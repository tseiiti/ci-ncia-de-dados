# %% [markdown]
# ## Instalando biblioteca do Twitter

# %%
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in c:\users\tseii\workspace\python\virtualenv\lib\site-packages (4.3.0)
# Requirement already satisfied: requests-oauthlib<2,>=1.0.0 in c:\users\tseii\workspace\python\virtualenv\lib\site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: requests<3,>=2.11.1 in c:\users\tseii\workspace\python\virtualenv\lib\site-packages (from tweepy) (2.26.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\tseii\workspace\python\virtualenv\lib\site-packages (from requests<3,>=2.11.1->tweepy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tseii\workspace\python\virtualenv\lib\site-packages (from requests<3,>=2.11.1->tweepy) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tseii\workspace\python\virtualenv\lib\site-packages (from requests<3,>=2.11.1->tweepy) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tseii\workspace\python\virtualenv\lib\site-packages (from requests<3,>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\tseii\workspace\python\virtualenv\lib\site-packages (from requests-oauthlib<2,>=1.0.0->tweepy) (3.1.1)

# %% [markdown]
# ### Documentação da biblioteca Tweepy
# https://docs.tweepy.org/en/latest/getting_started.html

# %%
import tweepy as tw
import pandas as pd

# %% [markdown]
# ## Chaves de acesso fornecidas pelo twitter
# ![image-3.png](imagens/image20.png)

# %% [markdown]
# # Abrir documento que contém as informções de acesso
#
# Vamos copiar as chaves de acesso fornecidas pelo twiter e salvar em um arquivo do tipo txt.
# Esse arquivo vamos salvar no diretório do projeto da coleta do Twitter.
#
# A ideia é ter as chaves salvas em um aquivo e depois criar um código em python para acessa-las lendo linha por linha e adicionando as variáveis para cada tipo de chave de acesso. Dessa forma, para cada linha do arquivo txt será a identificação de uma chave de acesso liberada pelo Twitter.

# %%
with open ("coleta_twitter_token.txt", "r") as file:
    consumer_key = file.readline().strip('\n') # elimina o caracter \n que é uma quebra de linha
    consumer_secret = file.readline().strip('\n')
    token = file.readline().strip('\n')
    access_token = file.readline().strip('\n')
    access_token_secret = file.readline().strip('\n')

# %% [markdown]
# ## Realizando autentificação na API do Twitter

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tw.API(auth) # Cria a conexão de acesso com o twitter

public_tweets = api.home_timeline() # Pega todos os primeiros twittes da timeline

# %% [markdown]
# ## Visualizando os tweets  públicos da time line

# %%
for tweet in public_tweets: # mostra os principais tweets da time line
    print(tweet.text)

# %% [markdown]
# ##  Extraindo tweets baseado em tema
#
# Para buscar os tweets vamos utilizar a função cursor da biblioteca tweepy.
# Para saber como utilizar o cursor podemos abrir a documentação da biblioteca. https://docs.tweepy.org/en/v3.5.0/cursor_tutorial.html

# %%
busca_palavras = "#vacina" #Cria uma variável que é atribuida as palavras que queremos extrair

# %%
# busca todos os tweets relacionado a(s) palavra(s) procuradas
tweets = tw.Cursor(api.search_tweets, # metodo da API para busrcar tweets
            q=busca_palavras).items(5) # especifica o número de tweets retornados

# %% [markdown]
# ### Verificando atributos disponibilização em um tweet

# %%
for tweet in tweets:
    print(tweet.user.name, tweet.text) # traz o texto contidos nos tweets
# Out:
# Notícia De Famosos | #RIPMM RT @sbtnews: PASSAPORTE DA VACINA - Medida define um comprovante de vacinação para entrada em países 📲 https://t.co/KJOljxtbLz #vacina #cor…
# ANDRÉ NIDECK Continue jogando doses mensais de sulfato de aluminio direto na sua corrente sanguinea, em experimentos que modific… https://t.co/oBQnCkUykh
# Aldair Rodrigues E Campina Grande que já atingiu mais de 70% dos leitos ocupados por pacientes da Covid-19 no Hospital Pedro 1, e ho… https://t.co/jObDMm4cfY
# Bot CoronaVirus RT @BrazilSFE: https://t.co/aLxKcT74Tu
# Coronavírus | Número de Pedidos de Patentes em Todo o Mundo
# ✔ Brazil SFE®
#
# @Wyeth
# @Zoetis
# @Merial
# @P…
# Brazil SFE https://t.co/aLxKcT74Tu
# Coronavírus | Número de Pedidos de Patentes em Todo o Mundo
# ✔ Brazil SFE®
#
# @Wyeth
# @Zoetis… https://t.co/HmjODkD02b

# %% [markdown]
# ## Verificando atributos chaves contidas dentro de um  tweet

# %%
tweet._json
# Out:
# {'created_at': 'Mon Dec 06 21:15:13 +0000 2021',
#  'id': 1467965877987561473,
#  'id_str': '1467965877987561473',
#  'text': 'https://t.co/aLxKcT74Tu\nCoronavírus | Número de Pedidos de Patentes em Todo o Mundo\n✔ Brazil SFE®\n\n@Wyeth\n@Zoetis… https://t.co/HmjODkD02b',
#  'truncated': True,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'Wyeth',
#     'name': 'Wyeth',
#     'id': 25585428,
#     'id_str': '25585428',
#     'indices': [99, 105]},
#    {'screen_name': 'Zoetis',
#     'name': 'Zoetis',
#     'id': 572929741,
#     'id_str': '572929741',
#     'indices': [106, 113]}],
#   'urls': [{'url': 'https://t.co/aLxKcT74Tu',
#     'expanded_url': 'https://bit.ly/2Xax6V0',
#     'display_url': 'bit.ly/2Xax6V0',
#     'indices': [0, 23]},
#    {'url': 'https://t.co/HmjODkD02b',
#     'expanded_url': 'https://twitter.com/i/web/status/1467965877987561473',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [115, 138]}]},
#  'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#  'source': '<a href="http://etus.com.br" rel="nofollow">Etus Brasil</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 2956693744,
#   'id_str': '2956693744',
#   'name': 'Brazil SFE',
#   'screen_name': 'BrazilSFE',
#   'location': 'São Paulo, Brasil',
#   'description': 'Brazil SFE®| We are passionate about improving our world with #Artificialintelligence, #Automation, #Analytics  #innovation #digital #ai #vr #ar #ml #rpa',
#   'url': 'https://t.co/Xz1EdtVASB',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/Xz1EdtVASB',
#       'expanded_url': 'http://brazilsfe.blogspot.com.br/',
#       'display_url': 'brazilsfe.blogspot.com.br',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 129,
#   'friends_count': 1364,
#   'listed_count': 22,
#   'created_at': 'Fri Jan 02 14:13:17 +0000 2015',
#   'favourites_count': 8293,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 85783,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1349793943525990403/Er5goVGt_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1349793943525990403/Er5goVGt_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2956693744/1485431005',
#   'profile_link_color': 'E81C4F',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 1,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'lang': 'pt'}

# %% [markdown]
# ## Visualizando tweets coletados

# %% [markdown]
# Cada tweet possui uma série de atributos
# Por exemplo:
#
#     1.  created_at: Data da publicação
#     2.  name: Contém o nome da pessoa
#     3.  description: Contém a descrição do usuário
#     4.  location: Local onde foi postado o tweet
#     5.  text - Texto que a pessoa postou

# %%
# Para facilitar a visualização
vars(tweet).keys() #retornar todas as chaves dentro de tweets
# Out:
# dict_keys(['_api', '_json', 'created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'source_url', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'author', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'possibly_sensitive', 'lang'])

# %%
vars(tweet.user).keys() #retorna todas as chaves dentro do atributo user
# Out:
# dict_keys(['_api', '_json', 'id', 'id_str', 'name', 'screen_name', 'location', 'description', 'url', 'entities', 'protected', 'followers_count', 'friends_count', 'listed_count', 'created_at', 'favourites_count', 'utc_offset', 'time_zone', 'geo_enabled', 'verified', 'statuses_count', 'lang', 'contributors_enabled', 'is_translator', 'is_translation_enabled', 'profile_background_color', 'profile_background_image_url', 'profile_background_image_url_https', 'profile_background_tile', 'profile_image_url', 'profile_image_url_https', 'profile_banner_url', 'profile_link_color', 'profile_sidebar_border_color', 'profile_sidebar_fill_color', 'profile_text_color', 'profile_use_background_image', 'has_extended_profile', 'default_profile', 'default_profile_image', 'following', 'follow_request_sent', 'notifications', 'translator_type', 'withheld_in_countries'])

# %%
print(tweet.user.name,'-',tweet.user.location)
# Out:
# Brazil SFE - São Paulo, Brasil

# %% [markdown]
# ## Retirando tweets repetidos
#
# Para retirar os tweets repetidos, vamos adicionar na string de busca o comando **"-filter:retweets"** para informar que não queremos informações de retweets

# %%
busca_palavras = "#vacina" + "-filter:retweets"
tweets = tw.Cursor(api.search_tweets,q=busca_palavras).items(5)

# visualizar tweets
for tweet in tweets:
    print( tweet.created_at, '\n',  tweet.user.name, '\n', tweet.text, '\n') # traz o texto contidos nos tweets
# Out:
# 2021-12-06 21:30:48+00:00
#  ANDRÉ NIDECK
#  Continue jogando doses mensais de sulfato de aluminio direto na sua corrente sanguinea, em experimentos que modific… https://t.co/oBQnCkUykh
#
# 2021-12-06 21:29:30+00:00
#  Aldair Rodrigues
#  E Campina Grande que já atingiu mais de 70% dos leitos ocupados por pacientes da Covid-19 no Hospital Pedro 1, e ho… https://t.co/jObDMm4cfY
#
# 2021-12-06 21:15:13+00:00
#  Brazil SFE
#  https://t.co/aLxKcT74Tu
# Coronavírus | Número de Pedidos de Patentes em Todo o Mundo
# ✔ Brazil SFE®
#
# @Wyeth
# @Zoetis… https://t.co/HmjODkD02b
#
# 2021-12-06 21:14:55+00:00
#  Leandro Carneiro
#  @PedroHallal Qualquer pessoa minimamente alfabetizada é capaz de entender a redução no número de mortes após a vaci… https://t.co/WOYLUWKdJr
#
# 2021-12-06 21:08:25+00:00
#  98 FM Natal
#  Mães de bebês que tomaram vacinas contra Covid por engano relatam desespero: ‘E se matasse minha filha?’ #vacina… https://t.co/RA0T0REYoI

# %% [markdown]
# ### Observação Importante
#
# O cursor é um método dinâmico. Dessa forma, todas as vezes que o método é executado novos resultados são retornados.
# Isso acontece porque os tweets são postados a todo minuto. Ou seja, a busca é em tempo real.
#
# O proximo passo é criar uma estrututa de armazenamento para salvar os tweets que estamos coletando.

# %% [markdown]
# ## Criando lista de armazenamento
# Vamos criar uma lista vazia e adicionando os dados coletados de os tweets.

# %%
busca_palavras = "#vacina" + "-filter:retweets" #Cria uma variável} que é atribuida as palavras que queremos extrair

# busca todos os tweets relacionado a(s) palavra(s) procuradas
tweets = tw.Cursor(api.search_tweets, # metodo da API para busrcar tweets
            q=busca_palavras).items(1500) # especifica o número de tweets retornados

# %%
# Para cada tweet em tweets, vamos coletar as informações dos atributos que queremos armazenar.
lista_tweets = []
for tweet in tweets:
    dados_tweet = []
    dados_tweet.append(tweet.created_at) 
    dados_tweet.append(tweet.user.name) 
    dados_tweet.append(tweet.user.description) 
    dados_tweet.append(tweet.user.location)
    dados_tweet.append(tweet.text)
    
    lista_tweets.append(dados_tweet)

# %%
lista_tweets[:5]
# Out:
# [[datetime.datetime(2021, 12, 6, 21, 30, 48, tzinfo=datetime.timezone.utc),
#   'ANDRÉ NIDECK',
#   'Engenheiro Civil, Guitarrista, Fluminense Futebol Clube & Conservador Liberal.',
#   'Praia de Itapoã, Vila Velha',
#   'Continue jogando doses mensais de sulfato de aluminio direto na sua corrente sanguinea, em experimentos que modific… https://t.co/oBQnCkUykh'],
#  [datetime.datetime(2021, 12, 6, 21, 29, 30, tzinfo=datetime.timezone.utc),
#   'Aldair Rodrigues',
#   'Jornalista-UEPB / Pós Graduando em Gestão Pública UEPB - Assessor de Imprensa Sec. Saúde CG',
#   'Campina Grande, Brasil',
#   'E Campina Grande que já atingiu mais de 70% dos leitos ocupados por pacientes da Covid-19 no Hospital Pedro 1, e ho… https://t.co/jObDMm4cfY'],
#  [datetime.datetime(2021, 12, 6, 21, 15, 13, tzinfo=datetime.timezone.utc),
#   'Brazil SFE',
#   'Brazil SFE®| We are passionate about improving our world with #Artificialintelligence, #Automation, #Analytics  #innovation #digital #ai #vr #ar #ml #rpa',
#   'São Paulo, Brasil',
#   'https://t.co/aLxKcT74Tu\nCoronavírus | Número de Pedidos de Patentes em Todo o Mundo\n✔ Brazil SFE®\n\n@Wyeth\n@Zoetis… https://t.co/HmjODkD02b'],
#  [datetime.datetime(2021, 12, 6, 21, 14, 55, tzinfo=datetime.timezone.utc),
#   'Leandro Carneiro',
#   '•Geografia na UFF.🌏\n•Pós graduação em Educação Ambiental.\n•Mestrado em Educação na UFRRJ\n•Vascaíno\n•Casado com @ElineCarneiro4 ❤️\n•Pai da Lêh e da Lana🌸🌸\n✝️',
#   '',
#   '@PedroHallal Qualquer pessoa minimamente alfabetizada é capaz de entender a redução no número de mortes após a vaci… https://t.co/WOYLUWKdJr'],
#  [datetime.datetime(2021, 12, 6, 21, 8, 25, tzinfo=datetime.timezone.utc),
#   '98 FM Natal',
#   'A toda hora, em todo lugar. O portal de notícias que mais cresce no RN: https://t.co/2Py842Hq0j https://t.co/b6VFXle1yf',
#   'Natal - RN',
#   'Mães de bebês que tomaram vacinas contra Covid por engano relatam desespero: ‘E se matasse minha filha?’ #vacina… https://t.co/RA0T0REYoI']]

# %% [markdown]
# ## Criando um dataframe para armzenamento da lista
#
# Vamos criar um dataframe passando a lista dos tweets

# %%
df_tweets = pd.DataFrame(lista_tweets, columns=['data', 'nome', 'descricao', 'localidade', 'post'])

# %%
df_tweets
# Out:
#                           data                                  nome  \
# 0    2021-12-06 21:30:48+00:00                          ANDRÉ NIDECK
# 1    2021-12-06 21:29:30+00:00                      Aldair Rodrigues
# 2    2021-12-06 21:15:13+00:00                            Brazil SFE
# 3    2021-12-06 21:14:55+00:00                      Leandro Carneiro
# 4    2021-12-06 21:08:25+00:00                           98 FM Natal
# ...                        ...                                   ...
# 1046 2021-11-28 11:58:14+00:00                          ElisioCoelho
# 1047 2021-11-28 11:50:24+00:00                            mspontocom
# 1048 2021-11-28 11:09:23+00:00  https://gettr.com/user/sergiofmoraes
# 1049 2021-11-28 09:16:18+00:00                    Jornal de Brasília
# 1050 2021-11-28 05:19:39+00:00                          Sinfo Angola
#
#                                               descricao  \
# 0     Engenheiro Civil, Guitarrista, Fluminense Fute...
# 1     Jornalista-UEPB / Pós Graduando em Gestão Públ...
# 2     Brazil SFE®| We are passionate about improving...
# 3     •Geografia na UFF.🌏\n•Pós graduação em Educaçã...
# 4     A toda hora, em todo lugar. O portal de notíci...
# ...                                                 ...
# 1046                Ver o mundo, pelos olhos de cada um
# 1047  Site de notícias: anti-corrupção, política, em...
# 1048  Estou aqui para denunciar  tudo de ruim  que a...
# 1049  O Jornal de Brasilia é um dos principais veícu...
# 1050  Conta de Paródia, sem vinculo com Estado\n\nLi...
#
#                        localidade  \
# 0     Praia de Itapoã, Vila Velha
# 1          Campina Grande, Brasil
# 2               São Paulo, Brasil
# 3
# 4                      Natal - RN
# ...                           ...
# 1046
# 1047            Campo Grande - MS
# 1048         @sergiofmoraes trump
# 1049                     Brasília
# 1050              Cazenga, Luanda
#
#                                                    post
# 0     Continue jogando doses mensais de sulfato de a...
# 1     E Campina Grande que já atingiu mais de 70% do...
# 2     https://t.co/aLxKcT74Tu\nCoronavírus | Número ...
# 3     @PedroHallal Qualquer pessoa minimamente alfab...
# 4     Mães de bebês que tomaram vacinas contra Covid...
# ...                                                 ...
# 1046  Eu ja tomei a minha 3°.\nTodos nós somos livre...
# 1047  #COVID19 #Covid #Covid_19 #COVID19pt #Passapor...
# 1048                    #vacina https://t.co/4gEqHSgVD5
# 1049  #Mundo #Vacina #Covid19\nO novo regulamento in...
# 1050  #AstraZeneca é uma empresa de #Langas da #RDC,...
#
# [1051 rows x 5 columns]

# %% [markdown]
# # Armazenando Tweets coletados no MongoDB
#
# ### instalando a biblioteca do Mongo para conexão com o banco de dados

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.0-cp39-cp39-win_amd64.whl (354 kB)
# Installing collected packages: pymongo
# Successfully installed pymongo-4.0

# %% [markdown]
# ### Importando o MongoClient para conexão e manipulação dos dados

# %%
from pymongo import MongoClient

# %% [markdown]
# ### Criando conexão com o banco de dados

# %%
conn = MongoClient('localhost', 27017)
type(conn)
# Out:
# pymongo.mongo_client.MongoClient

# %% [markdown]
# ## Criando instância do MongoDB
# ### Vamos criar implicitamente um banco de dados chamado tweetsdb

# %%
db = conn.tweetsdb
type(db)
# Out:
# pymongo.database.Database

# %% [markdown]
# ## Criando um coleção de documentos para ser armazenados no MongoDB

# %%
collection = db.tweets_coletados
type(collection)
# Out:
# pymongo.collection.Collection

# %% [markdown]
# Para que a operação da criação do banco tweetsdb e da coleção coleta_tweet seja efetivada, precisamos inserir um documento na coleção.

# %% [markdown]
# # Transformando o dataframe em um dicionario
# Os dados são armazenados no formato JSON no MongoDB. Deste modo, precisamos fazer o insert no banco através de uma estrutura de dados contendo chave e valor. Para isso vamos utilizar um dicionário.

# %%
tweets_dict = df_tweets.to_dict('records')
tweets_dict[:3]
# Out:
# [{'data': Timestamp('2021-12-06 21:30:48+0000', tz='UTC'),
#   'nome': 'ANDRÉ NIDECK',
#   'descricao': 'Engenheiro Civil, Guitarrista, Fluminense Futebol Clube & Conservador Liberal.',
#   'localidade': 'Praia de Itapoã, Vila Velha',
#   'post': 'Continue jogando doses mensais de sulfato de aluminio direto na sua corrente sanguinea, em experimentos que modific… https://t.co/oBQnCkUykh'},
#  {'data': Timestamp('2021-12-06 21:29:30+0000', tz='UTC'),
#   'nome': 'Aldair Rodrigues',
#   'descricao': 'Jornalista-UEPB / Pós Graduando em Gestão Pública UEPB - Assessor de Imprensa Sec. Saúde CG',
#   'localidade': 'Campina Grande, Brasil',
#   'post': 'E Campina Grande que já atingiu mais de 70% dos leitos ocupados por pacientes da Covid-19 no Hospital Pedro 1, e ho… https://t.co/jObDMm4cfY'},
#  {'data': Timestamp('2021-12-06 21:15:13+0000', tz='UTC'),
#   'nome': 'Brazil SFE',
#   'descricao': 'Brazil SFE®| We are passionate about improving our world with #Artificialintelligence, #Automation, #Analytics  #innovation #digital #ai #vr #ar #ml #rpa',
#   'localidade': 'São Paulo, Brasil',
#   'post': 'https://t.co/aLxKcT74Tu\nCoronavírus | Número de Pedidos de Patentes em Todo o Mundo\n✔ Brazil SFE®\n\n@Wyeth\n@Zoetis… https://t.co/HmjODkD02b'}]

# %% [markdown]
# ###  Quando um documento é inserido  é gerado uma chave especial chamada  "_id",
#
# Desta forma, ela é adiconada automaticamente se o documento não conter uma chave desse tipo '_id'

# %%
# Inserindo os dados do tweet na coleção no banco MongoDB
for tweet in tweets_dict:
    post_id = collection.insert_one(tweet)
    post_id.inserted_id

# %% [markdown]
# # Operações de consulta do MongoDB pelo Python

# %% [markdown]
# ## Verificando nome do banco criado

# %%
db.name
# Out:
# 'tweetsdb'

# %% [markdown]
# ## Verificando as coleções existentes

# %%
db.list_collection_names()
# Out:
# ['tweets_coletados']

# %% [markdown]
# ## Buscando dados do banco

# %%
import pprint # Biblioteca que facilita a visualização do tweets

# %%
for tweet in db.tweets_coletados.find().limit(5):
    print(tweet)

# %%
for tweet in db.tweets_coletados.find():
    pprint.pprint(tweet)
# Out:
# {'_id': ObjectId('61af1e009bf1e26220cdccbe'),
#  'data': datetime.datetime(2021, 12, 6, 21, 30, 48),
#  'descricao': 'Engenheiro Civil, Guitarrista, Fluminense Futebol Clube & '
#               'Conservador Liberal.',
#  'localidade': 'Praia de Itapoã, Vila Velha',
#  'nome': 'ANDRÉ NIDECK',
#  'post': 'Continue jogando doses mensais de sulfato de aluminio direto na sua '
#          'corrente sanguinea, em experimentos que modific… '
#          'https://t.co/oBQnCkUykh'}
# {'_id': ObjectId('61af1e009bf1e26220cdccbf'),
#  'data': datetime.datetime(2021, 12, 6, 21, 29, 30),
#  'descricao': 'Jornalista-UEPB / Pós Graduando em Gestão Pública UEPB - '
#               'Assessor de Imprensa Sec. Saúde CG',
#  'localidade': 'Campina Grande, Brasil',
#  'nome': 'Aldair Rodrigues',
#  'post': 'E Campina Grande que já atingiu mais de 70% dos leitos ocupados por '
#          'pacientes da Covid-19 no Hospital Pedro 1, e ho… '
#          'https://t.co/jObDMm4cfY'}
# {'_id': ObjectId('61af1e009bf1e26220cdccc0'),
#  'data': datetime.datetime(2021, 12, 6, 21, 15, 13),
#  'descricao': 'Brazil SFE®| We are passionate about improving our world with '
#               '#Artificialintelligence, #Automation, #Analytics  #innovation '
#               '#digital #ai #vr #ar #ml #rpa',
#  'localidade': 'São Paulo, Brasil',
#  'nome': 'Brazil SFE',
#  'post': 'https://t.co/aLxKcT74Tu\n'
#          'Coronavírus | Número de Pedidos de Patentes em Todo o Mundo\n'
#          '✔ Brazil SFE®\n'
#          '\n'
#          '@Wyeth\n'
#          '@Zoetis… https://t.co/HmjODkD02b'}
# {'_id': ObjectId('61af1e009bf1e26220cdccc1'),
#  'data': datetime.datetime(2021, 12, 6, 21, 14, 55),
#  'descricao': '•Geografia na UFF.🌏\n'
#               '•Pós graduação em Educação Ambiental.\n'
#               '•Mestrado em Educação na UFRRJ\n'
#               '•Vascaíno\n'
#               '•Casado com @ElineCarneiro4 ❤️\n'
#               '•Pai da Lêh e da Lana🌸🌸\n'
#               '✝️',
#  'localidade': '',
#  'nome': 'Leandro Carneiro',
#  'post': '@PedroHallal Qualquer pessoa minimamente alfabetizada é capaz de '
#          'entender a redução no número de mortes após a vaci… '
#          'https://t.co/WOYLUWKdJr'}
# {'_id': ObjectId('61af1e009bf1e26220cdccc2'),
#  'data': datetime.datetime(2021, 12, 6, 21, 8, 25),
#  'descricao': 'A toda hora, em todo lugar. O portal de notícias que mais '
#               'cresce no RN: https://t.co/2Py842Hq0j https://t.co/b6VFXle1yf',
#  'localidade': 'Natal - RN',
#  'nome': '98 FM Natal',
#  'post': 'Mães de bebês que tomaram vacinas contra Covid por engano relatam '
#          'desespero: ‘E se matasse minha filha?’ #vacina… '
#          'https://t.co/RA0T0REYoI'}
# {'_id': ObjectId('61af1e009bf1e26220cdccc3'),
#  'data': datetime.datetime(2021, 12, 6, 21, 2, 39),
#  'descricao': 'Site de notícias e entretenimento! A Bahia vista por todos os '
#               'ângulos; o Brasil e o mundo vistos do alto',
#  'localidade': 'Salvador - Bahia - Brasil ',
#  'nome': 'FarolDaBahia',
#  'post': 'Governo tem 48h para explicar a não exigência do passaporte da '
#          'vacina a quem desembarca no Brasil\n'
#          '\n'
#          '#passaporte… https://t.co/M2s8w564i6'}
# {'_id': ObjectId('61af1e009bf1e26220cdccc4'),
#  'data': datetime.datetime(2021, 12, 6, 21, 0),
#  'descricao': 'A sua fonte segura de informação. Siga também @sbtjornalismo.',
#  'localidade': '',
#  'nome': 'SBT News',
#  'post': 'PASSAPORTE DA VACINA - Medida define um comprovante de vacinação '
#          'para entrada em países 📲 https://t.co/KJOljxtbLz… '
#          'https://t.co/CEy0YuFEWA'}
# {'_id': ObjectId('61af1e009bf1e26220cdccc5'),
#  'data': datetime.datetime(2021, 12, 6, 20, 55, 1),
#  'descricao': 'Deputado Federal pelo PSB/PE. Ex-líder do PSB na Câmara. Por 6 '
#               "vezes um dos 'Cabeças do Congresso' (DIAP) e entre os 10 "
#               'melhores deputados pelo @congemfoco.',
#  'localidade': 'Brasília',
#  'nome': 'Tadeu Alencar',
#  'post': 'Terceira dose no braço e pronto para quantas forem necessárias. '
#          'Vacinas salvam vidas! Viva o SUS! \n'
#          '\n'
#          '#Vacina #SUS… https://t.co/l7VEsJhVFx'}
# {'_id': ObjectId('61af1e009bf1e26220cdccc6'),
#  'data': datetime.datetime(2021, 12, 6, 20, 52, 37),
#  'descricao': 'Faculdade Cásper Líbero.\n'
#               'Advogado OAB/SP 107785.\n'
#               'Comentarista da Jovem Pan. Apresentador da TV Gazeta.\n'
#               'Coach desde 2011.',
#  'localidade': 'São Paulo-SP',
#  'nome': 'Flavio Prado',
#  'post': 'Terceira dose. Se precisar, vamos mais. #vacina #COVID19 '
#          'https://t.co/5F42hHCmBP'}
# {'_id': ObjectId('61af1e009bf1e26220cdccc7'),
#  'data': datetime.datetime(2021, 12, 6, 20, 50, 45),
#  'descricao': 'Administrador formado, ex-estagiário, paraense, fã de tapioca e '
#               'maniçoba, roqueiro meio eclético, estranho, diferente e chato '
#               'pelo menos 24 horas por dia.',
#  'localidade': 'Rio de Janeiro, Brasil',
#  'nome': 'Eduardo Mendonça',
#  'post': 'Hoje eu tive alguns compromissos nas ruas de Belém do Pará. Foi bem '
#          'legal rever a minha madrinha, mesmo com os cuid… '
#          'https://t.co/9IW32ZwCgT'}
# {'_id': ObjectId('61af1e009bf1e26220cdccc8'),
#  'data': datetime.datetime(2021, 12, 6, 20, 20, 51),
#  'descricao': 'Você Conectado!\n'
#               '📊Cobertura dos principais acontecimentos da cidade\n'
#               '📝Jornalismo Local e Plural\n'
#               '📧#guarulhosonline\n'
#               '📲Siga o GO no Facebook e Instagram',
#  'localidade': 'Guarulhos, Brasil',
#  'nome': 'Guarulhos Online',
#  'post': 'Poupatempo Digital traz validação do certificado da vacina contra '
#          'Covid-19. #covid19 #guarulhos #poupatempo… https://t.co/UoaAJw18lL'}
# {'_id': ObjectId('61af1e009bf1e26220cdccc9'),
#  'data': datetime.datetime(2021, 12, 6, 20, 17, 40),
#  'descricao': 'Página oficial da Assembleia Legislativa do Estado do Ceará',
#  'localidade': 'Ceará',
#  'nome': 'Assembleia Legislativa do Estado do Ceará',
#  'post': 'Começa a valer exigência de comprovante de vacina da Covid-19 para '
#          'acesso à AL.\n'
#          '\n'
#          '#Alece #Vacina #Covid19… https://t.co/gv5eG0GwWW'}
# {'_id': ObjectId('61af1e009bf1e26220cdccca'),
#  'data': datetime.datetime(2021, 12, 6, 20, 11, 46),
#  'descricao': 'Somos o Laboratório de Bioquímica e Sinalização Celular, '
#               'Instituto de Biofísica Carlos Chagas Filho, UFRJ, chefiado pelo '
#               'Prof. Celso Caruso',
#  'localidade': 'Rio de Janeiro, Brasil',
#  'nome': 'LBSC UFRJ',
#  'post': 'A taxa média de hesitação vacinal nessa porção do continente está em '
#          'torno de 8%, enquanto entre o povo brasileiro… '
#          'https://t.co/onyJZwGfAn'}
# {'_id': ObjectId('61af1e009bf1e26220cdcccb'),
#  'data': datetime.datetime(2021, 12, 6, 19, 56, 36),
#  'descricao': 'O https://t.co/5WKQmuSbJw é um portal de notícias independente '
#               'e que se propõe a ser uma referência segura de conteúdo, '
#               'principalmente no momento de profusão das fake news.',
#  'localidade': 'Brasil',
#  'nome': 'Pleno.News',
#  'post': 'Projeto no Senado prevê punição por mortes e sequela da vacina\n'
#          '#vacina \n'
#          '\n'
#          'https://t.co/iGEScg9VaM'}
# {'_id': ObjectId('61af1e009bf1e26220cdcccc'),
#  'data': datetime.datetime(2021, 12, 6, 19, 47, 23),
#  'descricao': 'Notícias campanhas e logística de Proteção e Defesa Civil',
#  'localidade': 'Brasil',
#  'nome': 'Alertas & Análises',
#  'post': 'Jair Bolsonaro afirmou neste domingo que vai buscar alterar a '
#          'legislação para que apenas o governo federal possa de… '
#          'https://t.co/1XisJaOUOk'}
# {'_id': ObjectId('61af1e009bf1e26220cdcccd'),
#  'data': datetime.datetime(2021, 12, 6, 19, 40, 45),
#  'descricao': 'Jornalista',
#  'localidade': 'pelotas   |    rs   |   brasil',
#  'nome': 'luiz caminha',
#  'post': '3ª dose hoje, Pfizer. Vacina salva! Acredite! \n'
#          '#vacina #vacinasim #fakenewsnão em Porto Alegre, Rio Grande do Sul '
#          'https://t.co/5yqDKhgoZj'}
# {'_id': ObjectId('61af1e009bf1e26220cdccce'),
#  'data': datetime.datetime(2021, 12, 6, 19, 28, 37),
#  'descricao': 'Olá, UniCientistas! O canal é apresentado pelo Dr. Gustavo '
#               'Moreira, pesquisador e cientista formado em Biotecnologia. '
#               'Fique bem informado e divirta-se!',
#  'localidade': 'Brasil',
#  'nome': 'UniCiência',
#  'post': 'Entenda porque a variante Ômicron chocou o mundo!\n'
#          '\n'
#          'Assista! https://t.co/36DaeUK0nv\n'
#          '\n'
#          '#covid19 #variante #Omicron… https://t.co/J00q6zNEm1'}
# {'_id': ObjectId('61af1e009bf1e26220cdcccf'),
#  'data': datetime.datetime(2021, 12, 6, 19, 15, 12),
#  'descricao': 'Brazil SFE®| We are passionate about improving our world with '
#               '#Artificialintelligence, #Automation, #Analytics  #innovation '
#               '#digital #ai #vr #ar #ml #rpa',
#  'localidade': 'São Paulo, Brasil',
#  'nome': 'Brazil SFE',
#  'post': 'https://t.co/aLxKcT74Tu\n'
#          'Coronavírus | Número de Pedidos de Patentes em Todo o Mundo\n'
#          '✔ Brazil SFE®\n'
#          '\n'
#          '@Wyeth\n'
#          '@Zoetis… https://t.co/uHUxN1bFau'}
# {'_id': ObjectId('61af1e009bf1e26220cdccd0'),
#  'data': datetime.datetime(2021, 12, 6, 18, 59, 51),
#  'descricao': 'Série de podcasts sobre o movimento revolucionário comunista '
#               'nos EUA.',
#  'localidade': '',
#  'nome': 'AveVeritas',
#  'post': '#vacina experimental \n'
#          'Termo de Responsabilização para Eventos Adversos da Vacina '
#          'https://t.co/jPEVeyvfIQ'}
# {'_id': ObjectId('61af1e009bf1e26220cdccd1'),
#  'data': datetime.datetime(2021, 12, 6, 18, 50),
#  'descricao': 'Estamos seguindo um novo Norte! Fique bem informado!\n'
#               'Uma empresa do Grupo Norte de Comunicação.',
#  'localidade': 'Manaus - AM - BRAZIL',
#  'nome': 'Portal Norte de Notícias',
#  'post': '📍Santa Catarina e Roraima estão entre os estados que mais vacinaram. '
#          '#vacina\n'
#          '𝗟𝗲𝗶𝗮 𝗺𝗮𝗶𝘀 𝗮𝗰𝗲𝘀𝘀𝗮𝗻𝗱𝗼🔻\n'
#          'https://t.co/htcRiwX4sw'}
# {'_id': ObjectId('61af1e009bf1e26220cdccd2'),
#  'data': datetime.datetime(2021, 12, 6, 18, 40),
#  'descricao': 'Estamos seguindo um novo Norte! Fique bem informado!\n'
#               'Uma empresa do Grupo Norte de Comunicação.',
#  'localidade': 'Manaus - AM - BRAZIL',
#  'nome': 'Portal Norte de Notícias',
#  'post': '📍Santa Catarina e Roraima estão entre os estados que mais vacinaram. '
#          '#vacina \n'
#          '𝗟𝗲𝗶𝗮 𝗺𝗮𝗶𝘀 𝗮𝗰𝗲𝘀𝘀𝗮𝗻𝗱𝗼🔻\n'
#          'https://t.co/htcRixeFk4'}
# {'_id': ObjectId('61af1e009bf1e26220cdccd3'),
#  'data': datetime.datetime(2021, 12, 6, 18, 37, 14),
#  'descricao': 'Central Única dos Trabalhadores - Rio de Janeiro.',
#  'localidade': '',
#  'nome': 'CUT-Rio',
#  'post': 'A #Vacina se mostrando cada vez mais importante para combatermos o '
#          'vírus da #COVID19 https://t.co/AuqF200hRp'}
# {'_id': ObjectId('61af1e009bf1e26220cdccd4'),
#  'data': datetime.datetime(2021, 12, 6, 18, 34, 44),
#  'descricao': 'www.sigamais.com',
#  'localidade': 'Adamantina, SP, Brasil',
#  'nome': 'Siga Mais',
#  'post': 'https://t.co/Y3q6OsoFnN\n'
#          '\n'
#          'Horário de vacinação é ampliado no CIS. Veja também os horários da '
#          'Central Covid-19 para e… https://t.co/xItBkZqu7d'}
# {'_id': ObjectId('61af1e009bf1e26220cdccd5'),
#  'data': datetime.datetime(2021, 12, 6, 18, 16, 22),
#  'descricao': 'Notícias, entretenimento e atualidades',
#  'localidade': 'Barreiras, Brasil',
#  'nome': 'Fala Barreiras',
#  'post': 'LEM:\n'
#          'Cronograma de vacinação\n'
#          'Prefeitura de Luís Eduardo Magalhães divulga o cronograma de '
#          'vacinação até o próximo s… https://t.co/pqoZQaF9ti'}
# {'_id': ObjectId('61af1e009bf1e26220cdccd6'),
#  'data': datetime.datetime(2021, 12, 6, 18, 8, 54),
#  'descricao': 'https://t.co/3bkpgazCn3 \n'
#               'Jornal com sede na Cidade da Maia, nascido no digital, edita '
#               'uma revista mensal.',
#  'localidade': 'Maia',
#  'nome': 'Notícias Maia',
#  'post': 'Covid-19. Maia tem 90% da população com vacinação completa '
#          'https://t.co/jcroXPc2oq #coronavírus #covid-19 #Vacina '
#          '#VacinaCovid-19 #vacinação'}
# {'_id': ObjectId('61af1e009bf1e26220cdccd7'),
#  'data': datetime.datetime(2021, 12, 6, 17, 53, 41),
#  'descricao': 'A ISTOÉ Dinheiro é uma plataforma de informação sobre economia, '
#               'negócios, finanças, tecnologia e investimentos publicada pela '
#               'Editora Três.',
#  'localidade': 'Brasil',
#  'nome': 'ISTOÉ Dinheiro',
#  'post': 'Protesto contra restrições do coronavírus se torna violento em '
#          'Bruxelas.\n'
#          '\n'
#          '#protesto #bruxelas #coronavirus #COVID19… https://t.co/FEmgpZ9z0M'}
# {'_id': ObjectId('61af1e009bf1e26220cdccd8'),
#  'data': datetime.datetime(2021, 12, 6, 17, 50),
#  'descricao': 'Estamos seguindo um novo Norte! Fique bem informado!\n'
#               'Uma empresa do Grupo Norte de Comunicação.',
#  'localidade': 'Manaus - AM - BRAZIL',
#  'nome': 'Portal Norte de Notícias',
#  'post': '📍Sarah Gilbert pediu mais financiamento para a ciência. #pandemia '
#          '#vacina #estudo \n'
#          '𝗟𝗲𝗶𝗮 𝗺𝗮𝗶𝘀 𝗮𝗰𝗲𝘀𝘀𝗮𝗻𝗱𝗼🔻\n'
#          'https://t.co/3Sduopm9jx'}
# {'_id': ObjectId('61af1e009bf1e26220cdccd9'),
#  'data': datetime.datetime(2021, 12, 6, 17, 37, 25),
#  'descricao': 'O GMNC é o maior do Piauí. Através das Rádios MN FM, Boa FM, '
#               'Cocais FM, da TV Jornal, Rede MN, Jornal MN e '
#               'https://t.co/aPqnwYP6l1, levamos conteúdo regional pro Brasil',
#  'localidade': 'Teresina - Piauí',
#  'nome': 'Grupo Meio Norte de Comunicação',
#  'post': 'O Brasil deu início as aplicações da dose de reforço para os idosos '
#          'acima de 60 anos  https://t.co/hLHw1be3eD… https://t.co/TU2M3pB6jF'}
# {'_id': ObjectId('61af1e009bf1e26220cdccda'),
#  'data': datetime.datetime(2021, 12, 6, 17, 37, 4),
#  'descricao': 'Correspondente internacional no Chile/ Periodista brasileño '
#               'corresponsal en Chile',
#  'localidade': 'Santiago de Chile',
#  'nome': 'Rafael Carneiro',
#  'post': '🇧🇷Dose de reforço contra a covid-19\n'
#          '\n'
#          '🇨🇱Dosis de refuerzo contra el covid-19 \n'
#          '\n'
#          '#covid_19 #vᴀᴄᴜɴᴀcᴏᴠɪᴅ19 #vacúnate… https://t.co/coYP6erDmd'}
# {'_id': ObjectId('61af1e009bf1e26220cdccdb'),
#  'data': datetime.datetime(2021, 12, 6, 17, 33, 35),
#  'descricao': 'O S+ é um canal temático de saúde e bem-estar vocacionado para '
#               'quem trabalha e se interessa pela saúde. \n'
#               'Canal 129 NOS e MEO, canal 128 Vodafone Portugal',
#  'localidade': 'Lisboa, Portugal',
#  'nome': 'Canal S+',
#  'post': 'Mais 1,6 milhões de pessoas já receberam a dose de reforço da '
#          '#vacina contra a #covid19, cerca de 72 mil das quais… '
#          'https://t.co/yB2z5HvHuz'}
# {'_id': ObjectId('61af1e009bf1e26220cdccdc'),
#  'data': datetime.datetime(2021, 12, 6, 17, 30, 38),
#  'descricao': 'Deputado federal (PT-PR)\n'
#               'Economista, professor\n'
#               'Defensor da política feita por todos(as)',
#  'localidade': 'Paraná, Brasil',
#  'nome': 'Enio Verri',
#  'post': 'Cada dia que passa fica mais claro, defender a #vacina é defender a '
#          'vida! Fazer polêmica com a saúde das pessoas é… '
#          'https://t.co/WssO1uC8zq'}
# {'_id': ObjectId('61af1e009bf1e26220cdccdd'),
#  'data': datetime.datetime(2021, 12, 6, 17, 30),
#  'descricao': 'Sete dias por semana sem medo da notícia.',
#  'localidade': 'Fortaleza',
#  'nome': 'Ceará News 7',
#  'post': 'Para se vacinar, o caucaiense deve ter tomado a segunda dose há mais '
#          'de cinco meses.\n'
#          '\n'
#          'Para mais informações, acesse… https://t.co/UVfBnmb4px'}
# {'_id': ObjectId('61af1e009bf1e26220cdccde'),
#  'data': datetime.datetime(2021, 12, 6, 17, 21, 50),
#  'descricao': 'Somos o Laboratório de Investigação Pulmonar, do Instituto '
#               'de Biofísica Carlos Chagas Filho, UFRJ 🫁 Ciência Brasileira 🇧🇷 '
#               'Covid-19 🦠',
#  'localidade': 'Rio de Janeiro, Brasil',
#  'nome': 'LIP UFRJ',
#  'post': '(Fonte: Ministério da Saúde)\n'
#          '\n'
#          'Texto com participação especial da querida Beatriz Carniel do Ação '
#          'Covid 19\n'
#          'Arte por… https://t.co/Z9DPjxM72Y'}
# {'_id': ObjectId('61af1e009bf1e26220cdccdf'),
#  'data': datetime.datetime(2021, 12, 6, 17, 20, 24),
#  'descricao': 'A ISTOÉ Dinheiro é uma plataforma de informação sobre economia, '
#               'negócios, finanças, tecnologia e investimentos publicada pela '
#               'Editora Três.',
#  'localidade': 'Brasil',
#  'nome': 'ISTOÉ Dinheiro',
#  'post': 'Prefeito de Nova York anuncia vacinação obrigatória para o setor '
#          'privado.\n'
#          '\n'
#          '#novayork #NewYork #vacina #COVID19 #EUA… https://t.co/nGECTxqwV1'}
# {'_id': ObjectId('61af1e009bf1e26220cdcce0'),
#  'data': datetime.datetime(2021, 12, 6, 17, 20, 6),
#  'descricao': 'Produtora de shows! Próximo: Kiss. 🎶',
#  'localidade': 'São Paulo, Brasil',
#  'nome': 'Mercury Concerts',
#  'post': 'O Tommy Thayer já tomou a dose de reforço contra a COVID-19! Já '
#          'verificou quando é a sua vez?\n'
#          '\n'
#          'Consulte os canais d… https://t.co/TTOIKP63ki'}
# {'_id': ObjectId('61af1e009bf1e26220cdcce1'),
#  'data': datetime.datetime(2021, 12, 6, 17, 19, 13),
#  'descricao': 'Somos o portal de notícias mais acessado da PARAíBA. OBRIGADO '
#               'por nos acompanhar! Facebook: https://t.co/MKWZQ4NwAu '
#               'Instagram: https://t.co/vsrurJ4gSU',
#  'localidade': 'João Pessoa, PB',
#  'nome': 'Portal Correio',
#  'post': 'Percentual corresponde a um paciente. Com isso, a Secretaria de '
#          'Saúde dispõe, caso necessário, de 174 leitos para p… '
#          'https://t.co/haBfzm5vTo'}
# {'_id': ObjectId('61af1e009bf1e26220cdcce2'),
#  'data': datetime.datetime(2021, 12, 6, 17, 15, 13),
#  'descricao': 'Brazil SFE®| We are passionate about improving our world with '
#               '#Artificialintelligence, #Automation, #Analytics  #innovation '
#               '#digital #ai #vr #ar #ml #rpa',
#  'localidade': 'São Paulo, Brasil',
#  'nome': 'Brazil SFE',
#  'post': 'https://t.co/aLxKcT74Tu\n'
#          'Coronavírus | Número de Pedidos de Patentes em Todo o Mundo\n'
#          '✔ Brazil SFE®\n'
#          '\n'
#          '@Wyeth\n'
#          '@Zoetis… https://t.co/QTcrPM72fe'}
# {'_id': ObjectId('61af1e009bf1e26220cdcce3'),
#  'data': datetime.datetime(2021, 12, 6, 16, 30),
#  'descricao': 'A sua fonte segura de informação. Siga também @sbtjornalismo.',
#  'localidade': '',
#  'nome': 'SBT News',
#  'post': 'PASSAPORTE DA VACINA - Encontro deve colocar técnicos da Anvisa, '
#          'favoráveis à cobrança, frente a frente com represe… '
#          'https://t.co/O2AMXf8Uuh'}
# {'_id': ObjectId('61af1e009bf1e26220cdcce4'),
#  'data': datetime.datetime(2021, 12, 6, 16, 29, 14),
#  'descricao': 'Portal de notícias do Rio, Niterói, Maricá, SG, Itaboraí e '
#               'Região dos Lagos #enfoco',
#  'localidade': 'Niteroi, Rio de Janeiro',
#  'nome': 'Enfoco',
#  'post': 'https://t.co/nfOXyHYG3L #SaoGoncalo #Vacinacao #Vacina'}
# {'_id': ObjectId('61af1e009bf1e26220cdcce5'),
#  'data': datetime.datetime(2021, 12, 6, 16, 24, 17),
#  'descricao': '',
#  'localidade': '',
#  'nome': 'Bruna VACINA PELO AMOR DE DEUS',
#  'post': '#Ômicron #Covid @CoronavirusBra1 #vacina #vacinasalva\n'
#          '\n'
#          '@WHCOVIDResponse \n'
#          '\n'
#          'https://t.co/lDOYtcC3dP'}
# {'_id': ObjectId('61af1e009bf1e26220cdcce6'),
#  'data': datetime.datetime(2021, 12, 6, 16, 12, 3),
#  'descricao': 'Professor \n'
#               'Assessor & Consultor\n'
#               '\n'
#               'Doutor (ando); Mestre - USP\n'
#               'Ciências da Saúde\n'
#               '\n'
#               'Conteúdo: Saúde, Esporte, Cultura\n'
#               '\n'
#               'Contato profissional: \n'
#               'Via Mensagens twitter',
#  'localidade': 'São Paulo',
#  'nome': 'Prof. Alê Ribeiro',
#  'post': 'Adesão total da população a isolamento, máscara, vacinação deixa bem '
#          'claro no que realmente acredita 99% dos brasil… '
#          'https://t.co/iLbFYrMzsw'}
# {'_id': ObjectId('61af1e009bf1e26220cdcce7'),
#  'data': datetime.datetime(2021, 12, 6, 16, 4, 35),
#  'descricao': 'Plataforma Livre onde qualquer Autor pode publicar Livremente '
#               'suas Charges, Sátiras, Vídeos, Piadas, Tirinhas, Montagens, '
#               'Memes, Gifs. Solicite seu cadastro.',
#  'localidade': 'Brasília - DF',
#  'nome': 'Humor Político',
#  'post': '#AnoNovo #anovelho #Charge #muitavacina #queovírusnãoviralize '
#          '#vacina\n'
#          '\n'
#          'https://t.co/kDzbeS8NWi https://t.co/G5SiDSdODU'}
# {'_id': ObjectId('61af1e009bf1e26220cdcce8'),
#  'data': datetime.datetime(2021, 12, 6, 16, 2, 18),
#  'descricao': 'Desde 22 de março de 2011.\n'
#               '\n'
#               'Facebook: https://t.co/pzknJfVFbz\n'
#               '\n'
#               'Instagram: https://t.co/DjG5jgt5GG',
#  'localidade': 'Camaquã/RS',
#  'nome': 'Blog do Juares',
#  'post': 'Rio Grande do Sul está entre os estados que mais vacinaram: \r'
#          '\r'
#          ' #BlogdoJuares #covid19 #vacina #RioGrandedoSul… '
#          'https://t.co/VgA3Lhurif'}
# {'_id': ObjectId('61af1e009bf1e26220cdcce9'),
#  'data': datetime.datetime(2021, 12, 6, 16, 1, 10),
#  'descricao': 'VITOR SANTOS é jornalista,escritor, consultor, pesquisador, e '
#               'autor de vários artigos Facebook https://t.co/zr7gpVta8X…',
#  'localidade': 'Brasil',
#  'nome': 'Vitor Santos',
#  'post': 'O prefeito de Nova York anunciou hoje que a cidade vai exigir a '
#          'vacinação de todos os trabalhadores do setor privad… '
#          'https://t.co/JDBO2ZZGZG'}
# {'_id': ObjectId('61af1e009bf1e26220cdccea'),
#  'data': datetime.datetime(2021, 12, 6, 16, 0, 4),
#  'descricao': '📰 Arquivo de notícias Portuguesas\nhttps://t.co/llfHxHMoos',
#  'localidade': '',
#  'nome': 'Diurna',
#  'post': 'Palavras populares nas últimas 2 horas:\n'
#          '\n'
#          '#criancas #vacinacao #passageiros #transporte #aereo #habitantes '
#          '#diarios… https://t.co/u90ddd1ST0'}
# {'_id': ObjectId('61af1e009bf1e26220cdcceb'),
#  'data': datetime.datetime(2021, 12, 6, 15, 59, 47),
#  'descricao': 'Há oito anos, o Brasil de Fato RJ circula pelas ruas do Rio de '
#               'Janeiro e no meio online trazendo uma visão popular do Brasil e '
#               'do mundo aos cariocas.',
#  'localidade': 'Rio de Janeiro - Brasil',
#  'nome': 'Brasil de Fato RJ',
#  'post': '💉  VACINA INFLUENZA\n'
#          '\n'
#          'Vacinação contra a gripe segue suspensa no município do Rio de '
#          'Janeiro.\n'
#          '\n'
#          '➡️ Leia mais no Brasi… https://t.co/dkUsRZz4KJ'}
# {'_id': ObjectId('61af1e009bf1e26220cdccec'),
#  'data': datetime.datetime(2021, 12, 6, 15, 47, 11),
#  'descricao': 'Policial Militar, Paulista, de Direita, Ciclista, amo viajar... '
#               '#bike #ciclismo #religioso #católico #brasileiro',
#  'localidade': 'São Paulo - Brasil',
#  'nome': 'claunek miranda 🇧🇷🇺🇸🇺🇾',
#  'post': '#COVID19 #vacina https://t.co/Ofj6OMHYFp'}
# {'_id': ObjectId('61af1e009bf1e26220cdcced'),
#  'data': datetime.datetime(2021, 12, 6, 15, 38, 34),
#  'descricao': 'vascaíno gente boa.feliz com a família e os amigos que tenho e '
#               'com os inimigos que não tenho.\n'
#               'quer me enganar, me dá pudim de leite moça.',
#  'localidade': 'niteroi rj',
#  'nome': 'Julio Teixeira #Vasco123',
#  'post': '&amp;#8220;Próxima pandemia poderá ser pior&amp;#8221;, diz criadora '
#          'da AstraZeneca - Olhar Digital https://t.co/UWxcjcB5pN… '
#          'https://t.co/qAmPv4c35R'}
# {'_id': ObjectId('61af1e009bf1e26220cdccee'),
#  'data': datetime.datetime(2021, 12, 6, 15, 37, 22),
#  'descricao': 'Informação 24 horas por dia.\n'
#               '\n'
#               'Muito além da notícia, nada além da verdade.',
#  'localidade': 'Brasil',
#  'nome': 'BandNews TV',
#  'post': 'O prefeito de Nova York anunciou hoje que a cidade vai exigir a '
#          'vacinação de todos os trabalhadores do setor privad… '
#          'https://t.co/6rFTTrihEw'}
# {'_id': ObjectId('61af1e009bf1e26220cdccef'),
#  'data': datetime.datetime(2021, 12, 6, 15, 34, 21),
#  'descricao': 'Plataforma Livre onde qualquer Autor pode publicar Livremente '
#               'suas Charges, Sátiras, Vídeos, Piadas, Tirinhas, Montagens, '
#               'Memes, Gifs. Solicite seu cadastro.',
#  'localidade': 'Brasília - DF',
#  'nome': 'Humor Político',
#  'post': '#Charge #famíliafeliz #famíliavacinada #máscaras #ômicron #PapaiNoel '
#          '#vacina #Vacinação #xômicron… https://t.co/Tm13eItUjG'}
# {'_id': ObjectId('61af1e009bf1e26220cdccf0'),
#  'data': datetime.datetime(2021, 12, 6, 15, 24, 19),
#  'descricao': 'Professor \n'
#               'Assessor & Consultor\n'
#               '\n'
#               'Doutor (ando); Mestre - USP\n'
#               'Ciências da Saúde\n'
#               '\n'
#               'Conteúdo: Saúde, Esporte, Cultura\n'
#               '\n'
#               'Contato profissional: \n'
#               'Via Mensagens twitter',
#  'localidade': 'São Paulo',
#  'nome': 'Prof. Alê Ribeiro',
#  'post': '@g1 @g1\n'
#          'Wimbledon aplaudiu de pé Dra. Sarah, além dos aplausos, deveriam ter '
#          'entregue todo prêmio $ que foi para ve… https://t.co/kRCjE9MY3S'}
# {'_id': ObjectId('61af1e009bf1e26220cdccf1'),
#  'data': datetime.datetime(2021, 12, 6, 15, 18, 56),
#  'descricao': 'Professor \n'
#               'Assessor & Consultor\n'
#               '\n'
#               'Doutor (ando); Mestre - USP\n'
#               'Ciências da Saúde\n'
#               '\n'
#               'Conteúdo: Saúde, Esporte, Cultura\n'
#               '\n'
#               'Contato profissional: \n'
#               'Via Mensagens twitter',
#  'localidade': 'São Paulo',
#  'nome': 'Prof. Alê Ribeiro',
#  'post': '@o_antagonista @o_antagonista \n'
#          'Wimbledon aplaudiu de pé Dra. Sarah, além dos aplausos, deveriam ter '
#          'entregue todo p… https://t.co/KgaiA5GS3K'}
# {'_id': ObjectId('61af1e009bf1e26220cdccf2'),
#  'data': datetime.datetime(2021, 12, 6, 15, 17, 51),
#  'descricao': 'A História por trás da Notícia.\n#jornalismo #pontual',
#  'localidade': 'Manaus, Brasil',
#  'nome': 'Portal Pontual',
#  'post': '‼️ Presidente da África do Sul diz que variante ômicron avança e '
#          'apela por vacinação\n'
#          '\n'
#          '📌 Link da matéria completa no… https://t.co/FIPWXTyKIS'}
# {'_id': ObjectId('61af1e009bf1e26220cdccf3'),
#  'data': datetime.datetime(2021, 12, 6, 15, 17, 42),
#  'descricao': 'Digital bad influencer e coach desmotivacional. Desde 1983 '
#               'tentando entender o que é pra fazer.',
#  'localidade': 'São Paulo, BR',
#  'nome': 'Érison Martins',
#  'post': 'Embora alguns tentem fazer parecer o contrário, a pandemia ainda não '
#          'acabou. \n'
#          'Vacinemo-nos, amigos!\n'
#          'Vacinas salvam… https://t.co/qmZS9nVH02'}
# {'_id': ObjectId('61af1e009bf1e26220cdccf4'),
#  'data': datetime.datetime(2021, 12, 6, 15, 15, 13),
#  'descricao': 'Brazil SFE®| We are passionate about improving our world with '
#               '#Artificialintelligence, #Automation, #Analytics  #innovation '
#               '#digital #ai #vr #ar #ml #rpa',
#  'localidade': 'São Paulo, Brasil',
#  'nome': 'Brazil SFE',
#  'post': 'https://t.co/aLxKcT74Tu\n'
#          'Coronavírus | Número de Pedidos de Patentes em Todo o Mundo\n'
#          '✔ Brazil SFE®\n'
#          '\n'
#          '@Wyeth\n'
#          '@Zoetis… https://t.co/HSQneuLekh'}
# {'_id': ObjectId('61af1e009bf1e26220cdccf5'),
#  'data': datetime.datetime(2021, 12, 6, 15, 0, 56),
#  'descricao': 'Professor \n'
#               'Assessor & Consultor\n'
#               '\n'
#               'Doutor (ando); Mestre - USP\n'
#               'Ciências da Saúde\n'
#               '\n'
#               'Conteúdo: Saúde, Esporte, Cultura\n'
#               '\n'
#               'Contato profissional: \n'
#               'Via Mensagens twitter',
#  'localidade': 'São Paulo',
#  'nome': 'Prof. Alê Ribeiro',
#  'post': '@VEJA @VEJA\n'
#          'Wimbledon aplaudiu de pé Dra. Sarah, além dos aplausos, deveriam ter '
#          'entregue todo o prêmio $ que foi p… https://t.co/DvTCfdljCS'}
# {'_id': ObjectId('61af1e009bf1e26220cdccf6'),
#  'data': datetime.datetime(2021, 12, 6, 14, 59, 6),
#  'descricao': 'Voltei... p obsevar !!!!!\n'
#               'Direita conservadora \n'
#               'euautorizopresidente\n'
#               '\n'
#               'Leão , não só no signo! Personalidade idem!\n'
#               '🇧🇷🇧🇷🇧🇷🇧🇷',
#  'localidade': '',
#  'nome': 'Mel judice',
#  'post': '#Saude \n'
#          '#massademanobra \n'
#          '#Brasil #Mundo \n'
#          '#PassaporteSanitarioNao \n'
#          '#VacinaObrigatoriaNao \n'
#          '#vacina \n'
#          '#COVID19… https://t.co/yxcLHNkQ72'}
# {'_id': ObjectId('61af1e009bf1e26220cdccf7'),
#  'data': datetime.datetime(2021, 12, 6, 14, 49, 11),
#  'descricao': 'O Fonte Certa é um conceito de Jornalismo na #regiaodoslagos',
#  'localidade': 'Cabo Frio',
#  'nome': 'Fonte Certa',
#  'post': 'Para receber a terceira dose é necessário haver um período de cinco '
#          'meses da segunda dose\n'
#          '#vacina #pandemia… https://t.co/lvqnVWOtis'}
# {'_id': ObjectId('61af1e009bf1e26220cdccf8'),
#  'data': datetime.datetime(2021, 12, 6, 14, 36, 39),
#  'descricao': 'Sindicato dos Trabalhadres do Seguro Social e Previdência '
#               'Social no Estado de São Paulo',
#  'localidade': 'São Paulo',
#  'nome': 'SINSSP',
#  'post': 'De cada 10 pessoas que morreram por covid-19, oito não estavam '
#          'vacinados, de acordo com relatório encomendado pelo… '
#          'https://t.co/bBQ0TJTI9W'}
# {'_id': ObjectId('61af1e009bf1e26220cdccf9'),
#  'data': datetime.datetime(2021, 12, 6, 14, 29, 36),
#  'descricao': 'Perfil oficial do Diário do Rio Doce.\n'
#               'Notícias de GV, Minas e Brasil.\n'
#               '👇🏼Acesse👇🏼\n'
#               'https://t.co/iUuTATiIfa',
#  'localidade': 'Governador Valadares',
#  'nome': 'Diário do Rio Doce',
#  'post': '#covid19 #imunização #diarioriodoce #drd #minasgerais #novasvacinas '
#          '#vacina\n'
#          'https://t.co/hbeQbqCF7g'}
# {'_id': ObjectId('61af1e009bf1e26220cdccfa'),
#  'data': datetime.datetime(2021, 12, 6, 14, 18, 31),
#  'descricao': 'Jornale | redacao@jornale.com.br\n'
#               'TEL: (41) 3263-2002\n'
#               'Curitiba - Paraná\n'
#               'Notícias Online\n'
#               'Política / Cidade / Geral / Esportes / Cultura / Mundo',
#  'localidade': 'Curitiba, Brasil',
#  'nome': 'Jornale',
#  'post': '#pandemias #sarahgilbert #ciencia #saude #oxford #vacina #covid '
#          '#jornale #news\n'
#          'https://t.co/kkR83dYqWS'}
# {'_id': ObjectId('61af1e009bf1e26220cdccfb'),
#  'data': datetime.datetime(2021, 12, 6, 14, 18, 7),
#  'descricao': '🎁 https://t.co/M8oODdg1tT',
#  'localidade': 'Ruy Barbosa-BA, Brasil 🇧🇷',
#  'nome': 'Nanda',
#  'post': '💉100%\n#COVID19 #vacina https://t.co/vebvnuz5kF'}
# {'_id': ObjectId('61af1e009bf1e26220cdccfc'),
#  'data': datetime.datetime(2021, 12, 6, 14, 9, 5),
#  'descricao': 'O S+ é um canal temático de saúde e bem-estar vocacionado para '
#               'quem trabalha e se interessa pela saúde. \n'
#               'Canal 129 NOS e MEO, canal 128 Vodafone Portugal',
#  'localidade': 'Lisboa, Portugal',
#  'nome': 'Canal S+',
#  'post': 'O diretor do Programa Global da #Malária da @WHO apelou a uma '
#          '“operação maciça e urgente” para garantir que a… '
#          'https://t.co/BGH8mABbWW'}
# {'_id': ObjectId('61af1e009bf1e26220cdccfd'),
#  'data': datetime.datetime(2021, 12, 6, 14, 1, 53),
#  'descricao': 'Sou só mais uma carioca otaku,amo mascotes fofos que lembram '
#               'personagem de anime ^-^ Chuu! …ᘛ⁐̤ᕐᐷ',
#  'localidade': 'Brasil',
#  'nome': 'NezumiChuu',
#  'post': 'Acabei de ficar sabendo que se por milagre eu convencer meu pai a '
#          'tomar a primeira dose atrasada... Ele não vai enc… '
#          'https://t.co/fq16C0FWXV'}
# {'_id': ObjectId('61af1e009bf1e26220cdccfe'),
#  'data': datetime.datetime(2021, 12, 6, 14, 0, 1),
#  'descricao': 'Servidor público, defensor da Educação e vereador de São Paulo '
#               'pelo PSOL.',
#  'localidade': 'São Paulo, Brasil',
#  'nome': 'Celso Giannazi',
#  'post': 'Isso prova que a #Vacina funciona!    \n\nhttps://t.co/LMNhIKAuNa'}
# {'_id': ObjectId('61af1e009bf1e26220cdccff'),
#  'data': datetime.datetime(2021, 12, 6, 13, 50, 33),
#  'descricao': 'Twitter Oficial - Diretório Estadual do PSDB São Paulo',
#  'localidade': 'São Paulo',
#  'nome': 'PSDB SP - Estadual',
#  'post': 'Começando a semana com boas notícias. #Vida #Ciência #vacina '
#          'https://t.co/fQV7VODgZx'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd00'),
#  'data': datetime.datetime(2021, 12, 6, 13, 47, 55),
#  'descricao': '#Informação e análise jornalísticas com credibilidade, '
#               'qualidade e agilidade, baseadas nos princípios editoriais do '
#               'Jornal CORREIO DE MINAS.#ConselheiroLafaiete',
#  'localidade': 'Conselheiro Lafaiete, MG',
#  'nome': 'JornalCorreiodeMinas',
#  'post': 'Próxima pandemia pode ser mais grave, alerta criadora da vacina da '
#          'AstraZeneca #correiodeminas \n'
#          '\n'
#          '#pandemia… https://t.co/JHug29eAcC'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd01'),
#  'data': datetime.datetime(2021, 12, 6, 13, 42, 37),
#  'descricao': '🔊 Na versão on line.📱\n'
#               '📰 Impressa. 🗞\n'
#               '📽 TV Web. 💻\n'
#               'https://t.co/6SpA28hPxf',
#  'localidade': 'Manaus ',
#  'nome': 'Cenarium',
#  'post': '📲 A insuficiência nos registros civis tem impacto nas medidas para '
#          'controlar a pandemia ou avaliar os resultados; v… '
#          'https://t.co/3hDvCLKQjA'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd02'),
#  'data': datetime.datetime(2021, 12, 6, 13, 40, 55),
#  'descricao': 'Pref. de Vitória da Conquista/BA.',
#  'localidade': '',
#  'nome': 'pmvconquista',
#  'post': '💉 Vacinação contra a Covid-19 continua na segunda-feira com 1ª, 2ª e '
#          '3ª doses\n'
#          '\n'
#          'Veja: https://t.co/wWzfyqvWEz\n'
#          '\n'
#          '#PMVC #PrefsConquista #vacina'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd03'),
#  'data': datetime.datetime(2021, 12, 6, 13, 40, 27),
#  'descricao': 'Perfil oficial da Prefeitura de Goiânia',
#  'localidade': 'Goiânia, Brasil',
#  'nome': 'Prefeitura de Goiânia',
#  'post': '#Goiania ultrapassa 71% da população a partir de 12 anos totalmente '
#          'imunizada contra a #COVID19! Até agora, são mai… '
#          'https://t.co/jJe2srHb9T'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd04'),
#  'data': datetime.datetime(2021, 12, 6, 13, 39, 18),
#  'descricao': 'MANAUS | AMAZONAS | BRASIL | POLÍTICA | POLÍCIA | ESPORTE | '
#               'FAMOSOS 🕵🏽\u200d♂️',
#  'localidade': '',
#  'nome': 'Portal Vigilante',
#  'post': 'Na quarta-feira, 08, feriado, os pontos estratégicos e o da feira da '
#          'Banana não abrirão. #Manaus #Vacina https://t.co/ySEZMFZSbA'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd05'),
#  'data': datetime.datetime(2021, 12, 6, 13, 32, 55),
#  'descricao': 'O site antenado nas notícias do Amazonas e do Brasil',
#  'localidade': '',
#  'nome': 'O Antenado',
#  'post': 'Na quarta-feira, 08, feriado, os pontos estratégicos e o da feira da '
#          'Banana não abrirão. #Manaus #Vacina https://t.co/hE9xi6RzQQ'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd06'),
#  'data': datetime.datetime(2021, 12, 6, 13, 15, 13),
#  'descricao': 'Brazil SFE®| We are passionate about improving our world with '
#               '#Artificialintelligence, #Automation, #Analytics  #innovation '
#               '#digital #ai #vr #ar #ml #rpa',
#  'localidade': 'São Paulo, Brasil',
#  'nome': 'Brazil SFE',
#  'post': 'https://t.co/aLxKcT74Tu\n'
#          'Coronavírus | Número de Pedidos de Patentes em Todo o Mundo\n'
#          '✔ Brazil SFE®\n'
#          '\n'
#          '@Wyeth\n'
#          '@Zoetis… https://t.co/rnaAYeGLHP'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd07'),
#  'data': datetime.datetime(2021, 12, 6, 13, 3, 47),
#  'descricao': 'Secretário de Meio Ambiente e Sustentabilidade de Pernambuco. '
#               'Professor. Químico Industrial. Comunista do PCdoB. Nascido em '
#               'Caxias do Sul/RS.',
#  'localidade': 'Recife, Brasil',
#  'nome': 'José Bertotti',
#  'post': 'O passaporte de vacina salva vidas. Não ouça Bolsonaro, siga apenas '
#          'o bom senso!\n'
#          '\n'
#          '#Vacinação #Vacina… https://t.co/ibNRsGwytW'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd08'),
#  'data': datetime.datetime(2021, 12, 6, 13, 0, 46),
#  'descricao': '☯ Freguesia do Ó ZN.SP - Quiropraxia. Cuida da sua coluna e '
#               'alivia a Dor lombar crônica, em 90% após a 1ª Sessão. Esta com '
#               'Dor? Vai no Neto!',
#  'localidade': 'São Paulo SP',
#  'nome': 'Quiropraxia Zona Norte SP ☯',
#  'post': 'BOM DIA\n'
#          'https://t.co/WsmI2SCqmq \n'
#          '\n'
#          '#novidades  #g1  #saúde   #vacina  #TVCultura  #SP1 #SP2  '
#          '#redeglobo  #sbt  #r7… https://t.co/AEbhwVyOa7'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd09'),
#  'data': datetime.datetime(2021, 12, 6, 13, 0, 32),
#  'descricao': 'Na AlphaGraphics, nós damos vida às suas ideias.',
#  'localidade': 'Brasil',
#  'nome': 'AlphaGraphics Brasil',
#  'post': 'Já está disponível o 31º episódio da Vacina Semanal de Resultados '
#          'AlphaGraphics !\n'
#          '\n'
#          'https://t.co/Cmcno4rtaD\n'
#          '\n'
#          'Ótima s… https://t.co/BnhezK4q47'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd0a'),
#  'data': datetime.datetime(2021, 12, 6, 12, 59, 36),
#  'descricao': 'Tudo que sei, é que nada sei. E tenho pena dos que dizem que '
#               'sabem. Sigo aprendendo.',
#  'localidade': 'Rio de Janeiro, RJ, Brazil',
#  'nome': 'Frank 🌀',
#  'post': 'Como convencer os não vacinados de que as vacinas funcionam e, ao '
#          'mesmo tempo, convencer os vacinados a tomarem 3,… '
#          'https://t.co/PqkY9ybdPP'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd0b'),
#  'data': datetime.datetime(2021, 12, 6, 12, 55, 50),
#  'descricao': 'Católico. #Kanban, #Metrics and #Forecasting.\n'
#               'Accredited Kanban Trainer. \n'
#               'Kanban Coach Professional',
#  'localidade': 'Brasil',
#  'nome': 'Rodrigo Oliveira',
#  'post': 'https://t.co/QlwVNgIbJH\n\n#vacina #COVID19 🤡🤡🤡🤡🤡'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd0c'),
#  'data': datetime.datetime(2021, 12, 6, 12, 53, 4),
#  'descricao': 'Somos um portal de notícias, informações diárias sobre '
#               'política, economia, saúde, tecnologia, esporte e cultura, '
#               'pautas da Região Metropolitana de Belém.',
#  'localidade': '',
#  'nome': 'Belém Notícias',
#  'post': 'Veja quais municípios da Grande Belém vacinam hoje contra covid e '
#          'quais grupos têm direito\n'
#          '#vacina #vacinasalva\n'
#          '\n'
#          'https://t.co/PL01Fmb1LO'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd0d'),
#  'data': datetime.datetime(2021, 12, 6, 12, 43, 53),
#  'descricao': 'Plataforma Livre onde qualquer Autor pode publicar Livremente '
#               'suas Charges, Sátiras, Vídeos, Piadas, Tirinhas, Montagens, '
#               'Memes, Gifs. Solicite seu cadastro.',
#  'localidade': 'Brasília - DF',
#  'nome': 'Humor Político',
#  'post': '#antonio #Anvisa #barra #bolsonaro #Charges #como #da #estagiário '
#          '#fazer #mão #marcarcadocomaceitar #mesa #ômicron… '
#          'https://t.co/mtnndb5aHm'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd0e'),
#  'data': datetime.datetime(2021, 12, 6, 12, 31, 32),
#  'descricao': 'Associação Brasileira de Alergia e Imunologia',
#  'localidade': 'São Paulo - Brasil',
#  'nome': 'ASBAI',
#  'post': 'A ASBAI e a SBGG convidam médicos para a LIVE Imunoalergia no '
#          'Idoso.\n'
#          '\n'
#          'https://t.co/0QdnoSjyhY\n'
#          'Senha: 267216\n'
#          '\n'
#          '#idoso… https://t.co/Uev5ybjiN3'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd0f'),
#  'data': datetime.datetime(2021, 12, 6, 12, 25, 14),
#  'descricao': 'Entrou no meu perfil mas discorda da minha opinião, foda-se!',
#  'localidade': 'Goiânia, Brasil',
#  'nome': 'Sérgio Machado',
#  'post': '@jairbolsonaro por questão de "liberdade" eu preferia não pagar '
#          'imposto que não vejo retorno mas não posso por impo… '
#          'https://t.co/gBNE20Mew6'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd10'),
#  'data': datetime.datetime(2021, 12, 6, 12, 19, 19),
#  'descricao': '💒Cristã Católica \n'
#               '👨\u200d👩\u200d👧\u200d👦Conservadora \n'
#               '🔫Armamentista\n'
#               '🙍Antifeminista\n'
#               '🌎Antiglobalista\n'
#               '🤖🇧🇷 Robô do Bolsonaro',
#  'localidade': '',
#  'nome': 'Momo Sincera',
#  'post': 'É engraçado ver o esforço de pessoas tentando convencer os não '
#          'vacinados que a vacina funciona, e assim se vacinara… '
#          'https://t.co/isa2rtm0or'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd11'),
#  'data': datetime.datetime(2021, 12, 6, 12, 8, 35),
#  'descricao': 'A CAMTRA - Casa da Mulher Trabalhadora é uma organização '
#               'feminista fundada em 1997.',
#  'localidade': 'RJ, Brasil',
#  'nome': 'CAMTRA',
#  'post': '💉Vacine-se e cuide-se, até a pandemia acabar! \n'
#          '\n'
#          '⚠️Foram 1384 óbitos na última semana. \n'
#          'A Covid-19 continua afetando… https://t.co/4Zld14Mq2w'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd12'),
#  'data': datetime.datetime(2021, 12, 6, 12, 3, 59),
#  'descricao': 'Plataforma Livre onde qualquer Autor pode publicar Livremente '
#               'suas Charges, Sátiras, Vídeos, Piadas, Tirinhas, Montagens, '
#               'Memes, Gifs. Solicite seu cadastro.',
#  'localidade': 'Brasília - DF',
#  'nome': 'Humor Político',
#  'post': '#aceitar #antonio #Anvisa #barra #bolsonaro #Charge #estagiário '
#          '#fazer #mesa #papel #Passaporte #Presidente #torres… '
#          'https://t.co/Av274U4lcV'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd13'),
#  'data': datetime.datetime(2021, 12, 6, 12, 0, 17),
#  'descricao': 'Matutino generalista regional baseado na Região Autónoma da '
#               'Madeira.\n'
#               ' \n'
#               '@ImprovavelJM - Improvável a nova revista do JM',
#  'localidade': 'Funchal, Madeira',
#  'nome': 'JM MADEIRA',
#  'post': 'Pedro Ramos, secretário regional de Saúde e Proteção Civil, afirmou '
#          'hoje que as crianças com patologias, entre os 4… '
#          'https://t.co/uXvQEjXfLu'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd14'),
#  'data': datetime.datetime(2021, 12, 6, 11, 28, 52),
#  'descricao': '#Informação e análise jornalísticas com credibilidade, '
#               'qualidade e agilidade, baseadas nos princípios editoriais do '
#               'Jornal CORREIO DE MINAS.#ConselheiroLafaiete',
#  'localidade': 'Conselheiro Lafaiete, MG',
#  'nome': 'JornalCorreiodeMinas',
#  'post': 'PMCL vacina hoje (06) 2ª dose para quem vacinou com a Pfizer até o '
#          'dia 1/10 #correiodeminas \n'
#          '\n'
#          '#vacina #vacinação… https://t.co/OezAi5YPYl'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd15'),
#  'data': datetime.datetime(2021, 12, 6, 11, 27, 54),
#  'descricao': 'Perfil oficial do portal GP1',
#  'localidade': 'Teresina-PI',
#  'nome': 'GP1',
#  'post': 'A vacinação vai ocorrer em quatro pontos de drive. Serão ofertadas '
#          '1ª, 2ª e dose de reforço das vacinas.… https://t.co/3zYeFHGkyS'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd16'),
#  'data': datetime.datetime(2021, 12, 6, 11, 15, 12),
#  'descricao': 'Brazil SFE®| We are passionate about improving our world with '
#               '#Artificialintelligence, #Automation, #Analytics  #innovation '
#               '#digital #ai #vr #ar #ml #rpa',
#  'localidade': 'São Paulo, Brasil',
#  'nome': 'Brazil SFE',
#  'post': 'https://t.co/aLxKcT74Tu\n'
#          'Coronavírus | Número de Pedidos de Patentes em Todo o Mundo\n'
#          '✔ Brazil SFE®\n'
#          '\n'
#          '@Wyeth\n'
#          '@Zoetis… https://t.co/yRwspfvh3m'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd17'),
#  'data': datetime.datetime(2021, 12, 6, 10, 38, 9),
#  'descricao': 'O Grande Porto online',
#  'localidade': 'Porto, Portugal',
#  'nome': 'VIVA! Porto',
#  'post': 'Numa altura em que a toma da #vacina da #gripe tem sido um assunto '
#          'em destaque entre a população #portuguesa, a VIV… '
#          'https://t.co/JF2NvBRXj9'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd18'),
#  'data': datetime.datetime(2021, 12, 6, 10, 10, 32),
#  'descricao': 'Professor de História, Mestre em Educação, Antifascista, '
#               'Esquerda, Petista, Sindicalista, Roqueiro, Motoqueiro.  📚✊🚩🎤🛵',
#  'localidade': 'BRASIL',
#  'nome': 'Prof. Ricardo Klinker 🚩🚩🚩',
#  'post': 'Ir contra a #Ciencia e não tomar #vacina pra #Covid ou qualquer '
#          'outra, é o mesmo que pular do alto de um prédio por… '
#          'https://t.co/bNseQu6N5G'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd19'),
#  'data': datetime.datetime(2021, 12, 6, 10, 4, 6),
#  'descricao': 'Professor de História, Mestre em Educação, Antifascista, '
#               'Esquerda, Petista, Sindicalista, Roqueiro, Motoqueiro.  📚✊🚩🎤🛵',
#  'localidade': 'BRASIL',
#  'nome': 'Prof. Ricardo Klinker 🚩🚩🚩',
#  'post': 'Quem se nega a tomar #vacina deveria ser obrigado a assinar um '
#          'documento renunciando ao uso do #SUS caso tenha prob… '
#          'https://t.co/o2TkRFMbUX'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd1a'),
#  'data': datetime.datetime(2021, 12, 6, 9, 52, 29),
#  'descricao': 'O S+ é um canal temático de saúde e bem-estar vocacionado para '
#               'quem trabalha e se interessa pela saúde. \n'
#               'Canal 129 NOS e MEO, canal 128 Vodafone Portugal',
#  'localidade': 'Lisboa, Portugal',
#  'nome': 'Canal S+',
#  'post': 'Uma das criadoras da #vacina da @UniofOxford /@AstraZeneca defendeu '
#          'hoje que as futuras #pandemias podem ser mais l… '
#          'https://t.co/7GW5sx1lH8'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd1b'),
#  'data': datetime.datetime(2021, 12, 6, 9, 3, 49),
#  'descricao': 'Professor de História, Mestre em Educação, Antifascista, '
#               'Esquerda, Petista, Sindicalista, Roqueiro, Motoqueiro.  📚✊🚩🎤🛵',
#  'localidade': 'BRASIL',
#  'nome': 'Prof. Ricardo Klinker 🚩🚩🚩',
#  'post': 'UTIs voltando a se ocupar com vítimas da #COVID19,gente que Ñ tomou '
#          '#vacina porque Ñ quis. Se você tiver um infarto… '
#          'https://t.co/Sh3ssqXXEJ'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd1c'),
#  'data': datetime.datetime(2021, 12, 6, 9, 0, 1),
#  'descricao': '#Informação e análise jornalísticas com credibilidade, '
#               'qualidade e agilidade, baseadas nos princípios editoriais do '
#               'Jornal CORREIO DE MINAS.#ConselheiroLafaiete',
#  'localidade': 'Conselheiro Lafaiete, MG',
#  'nome': 'JornalCorreiodeMinas',
#  'post': 'Hoje (02) te repescagem para adolescentes de 12 a 17 anos que ainda '
#          'não tomaram a 1ª dose da vacina contra COVID-19… '
#          'https://t.co/G2SK6O22Er'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd1d'),
#  'data': datetime.datetime(2021, 12, 6, 8, 12, 39),
#  'descricao': 'Jornalista e Contadora de histórias do Cotidiano. Brazilian '
#               'Journalist in Österreich unterwegs. Contato: '
#               'dricaribasribas@gmail.com.',
#  'localidade': 'Viena, Áustria',
#  'nome': 'Adriana Ribasmayer✍️',
#  'post': 'A lei da obrigatoriedade da #vacina contra a #covid19 na #Austria '
#          'prevê multa de até 600 euros, a cada três meses.… '
#          'https://t.co/KVT5WwiXll'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd1e'),
#  'data': datetime.datetime(2021, 12, 6, 3, 42, 35),
#  'descricao': '',
#  'localidade': '',
#  'nome': '🕷angel 🕷',
#  'post': '🥺🥺\n #Anitta #COVID19 #vacina https://t.co/id5TFcEfgB'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd1f'),
#  'data': datetime.datetime(2021, 12, 6, 3, 15, 7),
#  'descricao': 'Brazil SFE®| We are passionate about improving our world with '
#               '#Artificialintelligence, #Automation, #Analytics  #innovation '
#               '#digital #ai #vr #ar #ml #rpa',
#  'localidade': 'São Paulo, Brasil',
#  'nome': 'Brazil SFE',
#  'post': 'https://t.co/aLxKcT74Tu\n'
#          'Coronavírus | Número de Pedidos de Patentes em Todo o Mundo\n'
#          '✔ Brazil SFE®\n'
#          '\n'
#          '@Wyeth\n'
#          '@Zoetis… https://t.co/95elDU9i8X'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd20'),
#  'data': datetime.datetime(2021, 12, 6, 2, 24),
#  'descricao': 'sou torcedor, não idiota.',
#  'localidade': '',
#  'nome': 'Palmeirense Verde',
#  'post': '@bodinholoiro Até o Wolverine vacinou, vacine -se já você tb.\n'
#          ' #vacina #'}
# {'_id': ObjectId('61af1e009bf1e26220cdcd21'),
#  'data': datetime.datetime(2021, 12, 6, 1, 15, 8),
#  'descricao': 'Brazil SFE®| We are passionate about improving our world with '
#               '#Artificialintelligence, #Automation, #Analytics  #innovation '
#               '#digital #ai #vr #ar #ml #rpa',
#  'localidade': 'São Paulo, Brasil',
# ...
# {'_id': ObjectId('61af1e019bf1e26220cdd0b6'),
#  'data': datetime.datetime(2021, 11, 29, 0, 30, 51),
#  'descricao': 'Acompanhe por aqui as notícias do #JornaldaCultura, #JTCultura '
#               'e #OpiniãoTVCultura',
#  'localidade': '',
#  'nome': 'Jornalismo TV Cultura',
#  'post': 'Diante do elevado número de mutações dessa nova variante, surge uma '
#          'questão urgente: as vacinas ainda serão eficaze… '
#          'https://t.co/8J5qrseLzI'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0b7'),
#  'data': datetime.datetime(2021, 11, 29, 0, 16, 13),
#  'descricao': 'E conhecerão a verdade, e a verdade os libertará". #joao8',
#  'localidade': 'Constelacao de orion',
#  'nome': 'Trinity',
#  'post': 'Já pegou seu cartão fidelidade #pfizer? #vacina '
#          'https://t.co/o5JTojoFVT'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0b8'),
#  'data': datetime.datetime(2021, 11, 28, 23, 58, 24),
#  'descricao': '♥️🖤 SIGO #FLAMENGUISTA. Sou “aquele cara” do @LeiSecaRJ. '
#               'Flamengo♥️🖤, Portela💙, BBB, Redes Sociais e de tudo um pouco '
#               'desde 2009 aqui',
#  'localidade': 'Rio de Janeiro, Brasil',
#  'nome': 'Edu Trevisan ♥️🖤🇧🇷🇺🇸',
#  'post': 'Cara de gato, bigode da gato e se bater mia…. Mas a #vacina '
#          'EXPERIMENTAL é um lindo coelhinho branquinho…. Assim va… '
#          'https://t.co/FoZDVfrDkw'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0b9'),
#  'data': datetime.datetime(2021, 11, 28, 23, 11, 17),
#  'descricao': 'meu diário',
#  'localidade': '',
#  'nome': 'Jordan',
#  'post': 'Esqueci de falar que eu tomei a #segundadose da #vacina '
#          'https://t.co/ndVGGr5pte'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0ba'),
#  'data': datetime.datetime(2021, 11, 28, 21, 47, 37),
#  'descricao': 'Essa conta é uma ideia. Ideias são a prova de tiranos!\n'
#               'Cansei de ser bonzinho e serei INSANO! \n'
#               'Não existe lógica para defender a #LIBERDADE!\n'
#               '#BrasilDireita',
#  'localidade': 'São Paulo SP Brasil ',
#  'nome': 'Wagner GEEK TOTAL',
#  'post': 'VOCE QUER TOMAR A #VACINA!?\n'
#          'TOME E VAI TOMAR NO C*!\n'
#          '\n'
#          'VOCE NAO QUER TOMAR ESSA MERDA!?\n'
#          'NÃO TOME E VAMOS VER QUEM NÃO… https://t.co/b1iy5B5ti6'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0bb'),
#  'data': datetime.datetime(2021, 11, 28, 20, 9, 33),
#  'descricao': 'A cada post um artigo científico',
#  'localidade': '',
#  'nome': 'Verum Vitae',
#  'post': 'Leia mais em\n'
#          '\n'
#          'https://t.co/BV1EBNubQ9\n'
#          '\n'
#          '#covid #omicron #vacina https://t.co/kFXZsgYoOT'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0bc'),
#  'data': datetime.datetime(2021, 11, 28, 19, 32, 53),
#  'descricao': 'O https://t.co/5WKQmuSbJw é um portal de notícias independente '
#               'e que se propõe a ser uma referência segura de conteúdo, '
#               'principalmente no momento de profusão das fake news.',
#  'localidade': 'Brasil',
#  'nome': 'Pleno.News',
#  'post': 'Boletim final confirma que Bruno Graf morreu por reação à vacina\n'
#          '#Vacina #Covid #BrunoGraf #PlenoNews\n'
#          'https://t.co/DkzMA3j6Vw'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0bd'),
#  'data': datetime.datetime(2021, 11, 28, 19, 8, 25),
#  'descricao': 'Sou uma rapariga normal que quer fazer novos amigos.\r\n'
#               ' Eu quero ser sempre a melhor em tudo o que me meto\r\n'
#               'Mal ou bem,adoro a minha familia linda.',
#  'localidade': 'lisboa',
#  'nome': 'andreia rodrigues',
#  'post': 'Reunião dos Ministros dos Negócios Estrangeiros decorreu em Santo '
#          'Domingo.\n'
#          '\n'
#          'https://t.co/NG5jOxUmxQ \n'
#          '\n'
#          '#Reuniao,… https://t.co/iev8Rv9PzR'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0be'),
#  'data': datetime.datetime(2021, 11, 28, 17, 50, 27),
#  'descricao': 'Ver o mundo, pelos olhos de cada um',
#  'localidade': '',
#  'nome': 'ElisioCoelho',
#  'post': 'A sério... ok ja estou pronto para a 4°... #vacina #Covid_19 '
#          '#Moderna https://t.co/Su7rBDw8Zd'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0bf'),
#  'data': datetime.datetime(2021, 11, 28, 17, 45, 5),
#  'descricao': 'Unternehmensberaterin. Lehrbeauftragte. '
#               'Aufsichtsrätin.Mediatorin. Interesse an Sozial- und '
#               'Frauenpolitik, Wirtschaft, Sport und Justizpolitik ⚖️ 🇧🇷 Brasil '
#               '💚',
#  'localidade': 'Salzburg - Wien',
#  'nome': 'Christine H. Seemann',
#  'post': 'Um motivação para tomar a vacina. So wird in Brasilien Werbung für '
#          'die Impfung gemacht. Da können wir uns noch viel… '
#          'https://t.co/OINjvKv3ri'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0c0'),
#  'data': datetime.datetime(2021, 11, 28, 17, 41, 39),
#  'descricao': '🖤 Corinthians🤍',
#  'localidade': 'Sorocaba - SP',
#  'nome': 'Jackson Emílio',
#  'post': 'Percebe-se que boa parte dos Bolsonaristas atingiram o fundo do poço '
#          'quando comemoram cada variante pra ressurgir o… '
#          'https://t.co/GqzgrGSbXq'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0c1'),
#  'data': datetime.datetime(2021, 11, 28, 17, 30, 44),
#  'descricao': 'Site de notícias e entretenimento! A Bahia vista por todos os '
#               'ângulos; o Brasil e o mundo vistos do alto',
#  'localidade': 'Salvador - Bahia - Brasil ',
#  'nome': 'FarolDaBahia',
#  'post': 'Laboratório na França inicia desenvolvimento de vacina contra o '
#          'câncer\n'
#          '\n'
#          '#laboratorio #franca #vacina #cancer… https://t.co/R5RxMhRUMm'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0c2'),
#  'data': datetime.datetime(2021, 11, 28, 17, 17, 5),
#  'descricao': '',
#  'localidade': '',
#  'nome': 'Leonardo Costa',
#  'post': 'Excelente notícia... No Brasil, a\n'
#          'Média móvel de mortes por Covid-19 segue abaixo de 300 pelo 26º dia '
#          'consecutivo!!… https://t.co/QY8AdVDihz'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0c3'),
#  'data': datetime.datetime(2021, 11, 28, 17, 10, 49),
#  'descricao': 'As notícias que você não pode perder diretamente da Sistema '
#               'Brasileiro de Comunicação. Para acompanhar siga.',
#  'localidade': 'Brasília, Brasil',
#  'nome': 'Sinal Verde',
#  'post': '🟢Segundo Barroso, na prática, as empresas seriam obrigadas a arcar '
#          'com os custos dos testes.\n'
#          '#TVAquarela… https://t.co/RtskLFXPrN'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0c4'),
#  'data': datetime.datetime(2021, 11, 28, 17, 8, 28),
#  'descricao': 'As notícias que você não pode perder diretamente da Sistema '
#               'Brasileiro de Comunicação. Para acompanhar siga.',
#  'localidade': 'Brasília, Brasil',
#  'nome': 'Sinal Verde',
#  'post': '🟢A portaria do governo\xa0foi contestada no Supremo\xa0por partidos '
#          'de esquerda como PT, PSB e Rede. Barroso, então, dete… '
#          'https://t.co/myvjIu7Qqs'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0c5'),
#  'data': datetime.datetime(2021, 11, 28, 16, 59, 39),
#  'descricao': 'As notícias que você não pode perder diretamente da Sistema '
#               'Brasileiro de Comunicação. Para acompanhar siga.',
#  'localidade': 'Brasília, Brasil',
#  'nome': 'Sinal Verde',
#  'post': '🟢A portaria também prevê testagem periódica dos funcionários para '
#          'que se garantam boas condições sanitárias no ambi… '
#          'https://t.co/RpAJ0PrUAf'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0c6'),
#  'data': datetime.datetime(2021, 11, 28, 16, 56, 42),
#  'descricao': 'As notícias que você não pode perder diretamente da Sistema '
#               'Brasileiro de Comunicação. Para acompanhar siga.',
#  'localidade': 'Brasília, Brasil',
#  'nome': 'Sinal Verde',
#  'post': '🟢Os três votos foram dados em julgamento que teve início na '
#          'sexta-feira 26 no plenário virtual da Corte.… '
#          'https://t.co/KzDpEx1VkI'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0c7'),
#  'data': datetime.datetime(2021, 11, 28, 16, 46, 40),
#  'descricao': 'As notícias que você não pode perder diretamente da Sistema '
#               'Brasileiro de Comunicação. Para acompanhar siga.',
#  'localidade': 'Brasília, Brasil',
#  'nome': 'Sinal Verde',
#  'post': '🟢A demissão de não vacinados contra a covid-19 pode ser aplicada '
#          'pelas empresas, segundo o entendimento de pelo men… '
#          'https://t.co/id5CEDVwXG'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0c8'),
#  'data': datetime.datetime(2021, 11, 28, 16, 0, 51),
#  'descricao': 'Especialista em Homeopatia - Atuação em Qualidade de vida, '
#               'estratégia Ortomolecular em Medicina e promoção de Hábitos '
#               'Saudáveis de Vida',
#  'localidade': 'Brasília - DF',
#  'nome': 'Ícaro A. Alcântara',
#  'post': 'https://t.co/zhB8TPJEW0\n'
#          '\n'
#          '#covid #covid19 #omicron #imunidade #vacina #vacinas '
#          'https://t.co/Wj94Yaa9nV'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0c9'),
#  'data': datetime.datetime(2021, 11, 28, 15, 47, 37),
#  'descricao': 'Pessoas que se encontram para colocar a ARTE, A CIÊNCIA '
#               'HUMANISTA, o PROTAGONISMO CIDADÃO e a ESPIRITUALIDADE a serviço '
#               'do BEM ESTAR e da FELICIDADE.',
#  'localidade': 'São Paulo, BRASIL',
#  'nome': 'Grupo do bem estar',
#  'post': '#VarianteÔmicron foi diagnosticada em 12 países e já deve circular '
#          'pelo #Brasil.Pandemia da #COVID19 não acabou.… '
#          'https://t.co/jJypqPkCLR'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0ca'),
#  'data': datetime.datetime(2021, 11, 28, 15, 15, 28),
#  'descricao': 'Fique por dentro dos principais fatos de hoje.',
#  'localidade': '',
#  'nome': 'AquarelaTV',
#  'post': '🟠Segundo Barroso, na prática, as empresas seriam obrigadas a arcar '
#          'com os custos dos testes.\n'
#          '#TVAquarela… https://t.co/PnREco6v1W'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0cb'),
#  'data': datetime.datetime(2021, 11, 28, 15, 9, 13),
#  'descricao': 'Amo AI que Gates Jobs e eu inventamos HiFi etc.low profile '
#               'negacao  que nao interessa?Mr B ona L Ft… B hided, vivo a minha '
#               'vida enquanto vivo',
#  'localidade': '',
#  'nome': 'Ireninha',
#  'post': '#Curiosa\n'
#          'Quem ? O #responsavel que largou  #idosos aem fila  merce do #frio '
#          '#para  conseguirem #vacina de #gripe  e… https://t.co/h5xrXiVXvz'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0cc'),
#  'data': datetime.datetime(2021, 11, 28, 15, 8, 59),
#  'descricao': 'Bolsonaro é nazifascista #blockchain #DeFi #ForaBolsonaro '
#               '#DitaduraNuncaMais',
#  'localidade': 'São Paulo, Brasil',
#  'nome': 'Navas',
#  'post': 'A maioria dos suíços aprova, em referendo, o certificado de '
#          'vacinação. 👏🎯\n'
#          '#ForaBolsonaro\n'
#          '#GreenpassObbligatorio… https://t.co/hBReNGM1jK'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0cd'),
#  'data': datetime.datetime(2021, 11, 28, 15, 6, 8),
#  'descricao': 'Sócia da BLW GAME BRASIL Ltda | \n'
#               'Tecnologia | Sustentabilidade | Se Cuida Mulheres 👇🏻',
#  'localidade': 'Rio de Janeiro, Brasil',
#  'nome': 'dani.santos',
#  'post': 'Bom Dia!!! Já estou vacinada contra  a gripe! 🙌🏻 \n'
#          'Já foi se vacinar contra a gripe? Ainda não! Vá ao posto ou procu… '
#          'https://t.co/OVxKXAFZAV'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0ce'),
#  'data': datetime.datetime(2021, 11, 28, 15, 5, 42),
#  'descricao': 'Fique por dentro dos principais fatos de hoje.',
#  'localidade': '',
#  'nome': 'AquarelaTV',
#  'post': '🟠A portaria do governo\xa0foi contestada no Supremo\xa0por partidos '
#          'de esquerda como PT, PSB e Rede. Barroso, então, dete… '
#          'https://t.co/MRLnbt63qD'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0cf'),
#  'data': datetime.datetime(2021, 11, 28, 14, 51, 53),
#  'descricao': 'Feita pra vestir o orgulho da nossa gente 🌵📦 Enviamos p/Brasil '
#               '💡 Por :@alyneabio',
#  'localidade': '',
#  'nome': 'Use Bee Nordeste 🌵',
#  'post': 'Não é hora de vacilar, é hora de VACINAR! Se vacine logo bença. '
#          '#vacina #vacinasim #vacinasalva https://t.co/82imvNJZQG'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0d0'),
#  'data': datetime.datetime(2021, 11, 28, 14, 46, 30),
#  'descricao': 'Especialista em Homeopatia - Atuação em Qualidade de vida, '
#               'estratégia Ortomolecular em Medicina e promoção de Hábitos '
#               'Saudáveis de Vida',
#  'localidade': 'Brasília - DF',
#  'nome': 'Ícaro A. Alcântara',
#  'post': 'https://t.co/zhB8TPJEW0\n'
#          '\n'
#          '#covid #covid19 #omicron #imunidade #vacina #vacinas '
#          'https://t.co/JJIHsuIBDp'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0d1'),
#  'data': datetime.datetime(2021, 11, 28, 14, 13, 17),
#  'descricao': '☯ Freguesia do Ó ZN.SP - Quiropraxia. Cuida da sua coluna e '
#               'alivia a Dor lombar crônica, em 90% após a 1ª Sessão. Esta com '
#               'Dor? Vai no Neto!',
#  'localidade': 'São Paulo SP',
#  'nome': 'Quiropraxia Zona Norte SP ☯',
#  'post': 'BOM DIA\n'
#          'https://t.co/WsmI2SCqmq \n'
#          '\n'
#          '#novidades  #g1  #saúde   #vacina  #TVCultura  #SP1 #SP2  '
#          '#redeglobo  #sbt  #r7… https://t.co/Fpndtzb58B'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0d2'),
#  'data': datetime.datetime(2021, 11, 28, 13, 13, 34),
#  'descricao': 'Fique  casa, a #micareta a gente pula depois.\n'
#               '#NãoConfioNasUrnasEletrônicas.\n'
#               'Voto auditável é transparência.',
#  'localidade': 'Minas Gerais, Brasil',
#  'nome': 'Edna Yay 🇧🇷 Pátria amada, BRASIL 🇧🇷',
#  'post': '@revistaoeste @geraldo1963 #Vachina, né. \n'
#          'Aquela que foi tão eficiente que vários picados foram #contaminados, '
#          'incl… https://t.co/mdU0e8YN4T'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0d3'),
#  'data': datetime.datetime(2021, 11, 28, 13, 0, 18),
#  'descricao': 'Crypto art, street art, type design and animation. Aliendígena, '
#               'disléxico, verborrágico e proparoxítono. Psicótico '
#               'Maníaco-Expansivo.',
#  'localidade': 'São Paulo',
#  'nome': 'tonydemarco.eth',
#  'post': 'Acabei te tomar uma Pfizer estupidamente  gelada como terceira dose. '
#          'Hic! #Covid #vacina #vacine #Pfizer #jacare'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0d4'),
#  'data': datetime.datetime(2021, 11, 28, 11, 58, 14),
#  'descricao': 'Ver o mundo, pelos olhos de cada um',
#  'localidade': '',
#  'nome': 'ElisioCoelho',
#  'post': 'Eu ja tomei a minha 3°.\n'
#          'Todos nós somos livres, mas por favor vacinem-se...\n'
#          '#vacina #Covid_19 #Gripe #COVID19pt… https://t.co/SMeUrBqQXN'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0d5'),
#  'data': datetime.datetime(2021, 11, 28, 11, 50, 24),
#  'descricao': 'Site de notícias: anti-corrupção, política, empregos, cursos, '
#               'concursos,astronomia. Notícias do MS e Brasil,',
#  'localidade': 'Campo Grande - MS',
#  'nome': 'mspontocom',
#  'post': '#COVID19 #Covid #Covid_19 #COVID19pt #PassaporteSanitarioNao '
#          '#passaportcovid #vacina #VacinasSalvamVidas… https://t.co/ZKHQU4zeXS'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0d6'),
#  'data': datetime.datetime(2021, 11, 28, 11, 9, 23),
#  'descricao': 'Estou aqui para denunciar  tudo de ruim  que acontece no Brasil',
#  'localidade': '@sergiofmoraes trump',
#  'nome': 'https://gettr.com/user/sergiofmoraes',
#  'post': '#vacina https://t.co/4gEqHSgVD5'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0d7'),
#  'data': datetime.datetime(2021, 11, 28, 9, 16, 18),
#  'descricao': 'O Jornal de Brasilia é um dos principais veículos da capital, '
#               'atingindo um extenso público, com enorme e conceituada '
#               'credibilidade.',
#  'localidade': 'Brasília',
#  'nome': 'Jornal de Brasília',
#  'post': '#Mundo #Vacina #Covid19\n'
#          'O novo regulamento interno leva em consideração evidências '
#          'científicas de que a proteção of… https://t.co/vEtPbszEak'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0d8'),
#  'data': datetime.datetime(2021, 11, 28, 5, 19, 39),
#  'descricao': 'Conta de Paródia, sem vinculo com Estado\n'
#               '\n'
#               'Lider da Guerra Memetica de Angola\n'
#               'Se nao gostou do tweet manteiga.',
#  'localidade': 'Cazenga, Luanda',
#  'nome': 'Sinfo Angola',
#  'post': '#AstraZeneca é uma empresa de #Langas da #RDC, pois mal lançaram '
#          '#covid #Omicron no mercado que os niggahs já tem… '
#          'https://t.co/kUmVLklULi'}

# %% [markdown]
# ## Realizando consulta no MongoDB utilizando o parâmentro de nome de usuário
#
# Observação importante: A consulta abaixo realiza uma pesquisa de um usuário especifico que foi coletado na última extração dos tweets. Dessa forma, coletas futuras podem não conter tweets desse usuário em específico. Se isso acontecer, a consulta pode não trazer nenhum resultado. Para fins de testes, vocês podem alterar o nome do usuário a partir das suas coletas.

# %%
for tweet in db.tweets_coletados.find({"nome": "Sinfo Angola"}):
    pprint.pprint(tweet)
# Out:
# {'_id': ObjectId('61af1e019bf1e26220cdcec2'),
#  'data': datetime.datetime(2021, 12, 4, 2, 5),
#  'descricao': 'Conta de Paródia, sem vinculo com Estado\n'
#               '\n'
#               'Lider da Guerra Memetica de Angola\n'
#               'Se nao gostou do tweet manteiga.',
#  'localidade': 'Cazenga, Luanda',
#  'nome': 'Sinfo Angola',
#  'post': 'Nos em #Angola fizemos o #copypast com orgulho, basta o governo '
#          'dizer que a #vacina é gratuita ... Que o medo gasta… '
#          'https://t.co/YgzryTRNko'}
# {'_id': ObjectId('61af1e019bf1e26220cdcec4'),
#  'data': datetime.datetime(2021, 12, 4, 1, 27),
#  'descricao': 'Conta de Paródia, sem vinculo com Estado\n'
#               '\n'
#               'Lider da Guerra Memetica de Angola\n'
#               'Se nao gostou do tweet manteiga.',
#  'localidade': 'Cazenga, Luanda',
#  'nome': 'Sinfo Angola',
#  'post': 'Um vírus com uma taxa de sobrevivência de 98%, usa #vacina que não '
#          'impede o contagio ou doença grave, + garante 100… '
#          'https://t.co/SM5mrwPo4U'}
# {'_id': ObjectId('61af1e019bf1e26220cdcf94'),
#  'data': datetime.datetime(2021, 12, 2, 1, 12),
#  'descricao': 'Conta de Paródia, sem vinculo com Estado\n'
#               '\n'
#               'Lider da Guerra Memetica de Angola\n'
#               'Se nao gostou do tweet manteiga.',
#  'localidade': 'Cazenga, Luanda',
#  'nome': 'Sinfo Angola',
#  'post': 'Ja tomou sua decima sexta dose de #vacina contra a #Covid ?\n'
#          '\n'
#          '#Omicron ja esta na cidade !'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0af'),
#  'data': datetime.datetime(2021, 11, 29, 9, 42),
#  'descricao': 'Conta de Paródia, sem vinculo com Estado\n'
#               '\n'
#               'Lider da Guerra Memetica de Angola\n'
#               'Se nao gostou do tweet manteiga.',
#  'localidade': 'Cazenga, Luanda',
#  'nome': 'Sinfo Angola',
#  'post': '@LuatyBeirao Quando todos forem vacinados com vigésima terceira '
#          'dose, o Covid desaparecera da face da terra\n'
#          '\n'
#          'Confia… https://t.co/UuZeapTlLq'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0b4'),
#  'data': datetime.datetime(2021, 11, 29, 1, 43),
#  'descricao': 'Conta de Paródia, sem vinculo com Estado\n'
#               '\n'
#               'Lider da Guerra Memetica de Angola\n'
#               'Se nao gostou do tweet manteiga.',
#  'localidade': 'Cazenga, Luanda',
#  'nome': 'Sinfo Angola',
#  'post': 'São estas as pessoas normais que querem colocar embargo #raxista '
#          'contra #Afriva, o continente com menos mortos e do… '
#          'https://t.co/riEgKVjkkr'}
# {'_id': ObjectId('61af1e019bf1e26220cdd0d8'),
#  'data': datetime.datetime(2021, 11, 28, 5, 19, 39),
#  'descricao': 'Conta de Paródia, sem vinculo com Estado\n'
#               '\n'
#               'Lider da Guerra Memetica de Angola\n'
#               'Se nao gostou do tweet manteiga.',
#  'localidade': 'Cazenga, Luanda',
#  'nome': 'Sinfo Angola',
#  'post': '#AstraZeneca é uma empresa de #Langas da #RDC, pois mal lançaram '
#          '#covid #Omicron no mercado que os niggahs já tem… '
#          'https://t.co/kUmVLklULi'}

# %% [markdown]
# ## Contanto um número de tweets dentro da coleção

# %%
db.tweets_coletados.estimated_document_count()
# Out:
# 1051

# %%
db.tweets_coletados.count_documents({})
# Out:
# 1051

# %% [markdown]
# ## Importando dados de um aquivo Json
#
# Vamos aprender a importar dados de um arquivo Json para dentro do MongoDB
#
# ![image.png](imagens/image21.png)

# %% [markdown]
# ### Importando a biblioteca do JSON

# %%
import json

# %% [markdown]
# ### Realizando leitura do arquivo

# %%
# leitura do arquivo texto
with open('coleta_twitter_chess.json', 'r') as file:
    data = file.read()

# transforma texto em json
json_dados = json.loads(data)

# %% [markdown]
# ### Verificando estrutura de chaves do arquivo JSON

# %%
json_dados.keys()
# Out:
# dict_keys(['user'])

# %% [markdown]
# ### Criando novo banco chamado pessoadb

# %%
db = conn.pessoadb
type(db)
# Out:
# pymongo.database.Database

# %% [markdown]
# ### Criando nova coleção chamada dados_pessoais

# %%
collection = db.dados_pessoais

# %% [markdown]
# ### Inserindo dados do arquivo JSON no banco MongoDB

# %%
for dado in json_dados['user']:
    dado_id = collection.insert_one(dado)
    dado_id.inserted_id

# %% [markdown]
# ### Verificando quantidade de registros dentro da coleção

# %%
db.dados_pessoais.estimated_document_count()
# Out:
# 1332

# %% [markdown]
# ### Visualizando dados inseridos

# %%
for dados in db.dados_pessoais.find().limit(2):
    pprint.pprint(dados)
# Out:
# {'@id': 'https://api.chess.com/pub/player/123lt',
#  '_id': ObjectId('61af33ba9bf1e26220cdd0d9'),
#  'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/18800602.e26b721f.200x200o.e738019a328a.jpeg',
#  'country': 'https://api.chess.com/pub/country/CN',
#  'followers': 36,
#  'is_streamer': False,
#  'joined': 1410059361,
#  'last_online': 1615967972,
#  'name': 'Tingjie Lei',
#  'player_id': 18800602,
#  'status': 'premium',
#  'title': 'GM',
#  'url': 'https://www.chess.com/member/123lt',
#  'username': '123lt'}
# {'@id': 'https://api.chess.com/pub/player/124chess',
#  '_id': ObjectId('61af33ba9bf1e26220cdd0da'),
#  'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/29499974.39041f89.200x200o.f6478a5ae8e2.jpeg',
#  'country': 'https://api.chess.com/pub/country/RU',
#  'followers': 87,
#  'is_streamer': False,
#  'joined': 1471316272,
#  'last_online': 1616173422,
#  'location': 'Красноярск',
#  'name': 'Дмитрий Хегай',
#  'player_id': 29499974,
#  'status': 'premium',
#  'title': 'GM',
#  'url': 'https://www.chess.com/member/124chess',
#  'username': '124chess'}

# %%
import requests
from IPython.display import Image, display

for dados in db.dados_pessoais.find().limit(3):
	res = requests.get(dados['country']).json()
	print(res['name'])
	# print(dados['avatar'])
	display(Image(dados['avatar']))
# Out:
# China
# Russia
# Serbia
